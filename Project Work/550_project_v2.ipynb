# %% [markdown]
# # **OPTIMIZING LOAN APPROVALS**
# ### **A Data-Driven Model For Assessing Installment-to-Income Risk**
#
# *A DSCI 550 Group Project (Spring 2024)*
#
# **Created by**
# - Jinwen “Eddie” Zhao
# - Jackson Crawford
# - Cameron Ela
# - Ravish Kamath

# %% [markdown]
# ## Introduction
#
# **Objective**
# - Improve loan default for peer-to-peer loans (LendingClub)
#
# **Background**
# - Current models underperforming negatively affecting loan decision-making. Non-gurantee of future results. (Cornell 2020 Study)
#
# **Task**
# - Develop an advanced model to predict default probabilities including both quantitative and behaviorial factors.
#
# **Goal**
# - Refine loan approval criteria to manage risk effectively.

# %% [markdown]
# ## Question and Hypothesis
#
# ***Does a higher installment-to-income ratio increase the likelihood of loan defaults on the LendingCLub platform?***
#
# **Hypothesis**:
# - The ratio of loan installments to annual income is directly associated with an increased risk of loan default, suggesting that borrowers whose loan repayments constitute a larger fraction of their income are more prone to financial distress, leading to a higher probability of default.

# %% [markdown]
# ## Dataset and Libraries

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#### FOR GOOGLE COLLAB CONNECTION
# from google.colab import drive
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# # Reading the loan_light.csv file
#
# loan_light = pd.read_csv("/content/drive/MyDrive/DSCI550_project/loan_light.csv")
# loan = loan_light   # Make a hard copy of the database called "loan" so it doesn't get messed up afterward
# columns = loan.columns
# loan.head()

# %%
loan_light = pd.read_csv("loan_light.csv")
# Make a hard copy of the database called "loan" so it doesn't get messed up afterward
loan = loan_light.copy()

loan_light.head()
# Out:
#    annual_inc application_type  avg_cur_bal  chargeoff_within_12_mths  \
# 0     80000.0       Individual       6746.0                       0.0
# 1     60000.0       Individual      13623.0                       0.0
# 2     78000.0       Individual      11011.0                       0.0
# 3     62000.0       Individual       9679.0                       0.0
# 4     49000.0       Individual       4925.0                       0.0
#
#    delinq_2yrs    dti  emp_length grade  inq_last_12m  installment  ...  \
# 0          0.0  15.12          10     B           1.0       743.75  ...
# 1          0.0  12.32           7     D           0.0       286.73  ...
# 2          0.0  25.00           1     D           6.0       869.66  ...
# 3          0.0  22.32           9     D           7.0       713.96  ...
# 4          0.0  32.43          10     D           0.0       366.51  ...
#
#    num_actv_bc_tl  pub_rec_bankruptcies  home_ownership term  mort_acc  \
# 0             1.0                   0.0             OWN   36       0.0
# 1             3.0                   0.0        MORTGAGE   60       1.0
# 2             4.0                   0.0        MORTGAGE   60       3.0
# 3             2.0                   0.0            RENT   36       4.0
# 4             4.0                   0.0            RENT   36       0.0
#
#    num_tl_90g_dpd_24m             purpose  year  loan_default        job
# 0                 0.0  debt_consolidation  2016             1  principal
# 1                 0.0         credit_card  2017             0      other
# 2                 0.0  debt_consolidation  2015             0    analyst
# 3                 0.0  debt_consolidation  2017             1      other
# 4                 0.0  debt_consolidation  2017             1     driver
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Description of Dataset:
# The dataset was obtained through a statistics professor at York University, who provided multiple real-life datasets ranging from bank data to real-estate datasets. We specifically chose a bank loan dataset. We are looking at 5000 loan requests issued by a bank, with each data point having 21 features. The table contains vital information to determine if a bank should loan to clients, such as whether they have defaulted before, how much annual income they had in previous years, how much they are borrowing, their jobs, and the rating of the loan. The dataset is already cleaned and easily interpreted by a human viewer. It has few ambiguous entries and empty values. After a bit of cleaning, the dataset will be ready for Python machine learning.
#
# The following spreadsheet will be explaining what does each parameter mean. Note that we are interested in the loan_default value.

# %%
# loan_param = pd.read_excel('/content/drive/MyDrive/DSCI550_project/loan_param.xlsx')
# loan_param.style.set_properties(subset=['Description'], **{'width': '1000px'})

# %%
loan_param = pd.read_excel('loan_param.xlsx')
loan_param.style.set_properties(subset=['Description'], **{'width': '1000px'})
# Out:
# <style type="text/css">
# #T_a1f6b_row0_col1, #T_a1f6b_row1_col1, #T_a1f6b_row2_col1, #T_a1f6b_row3_col1, #T_a1f6b_row4_col1, #T_a1f6b_row5_col1, #T_a1f6b_row6_col1, #T_a1f6b_row7_col1, #T_a1f6b_row8_col1, #T_a1f6b_row9_col1, #T_a1f6b_row10_col1, #T_a1f6b_row11_col1, #T_a1f6b_row12_col1, #T_a1f6b_row13_col1, #T_a1f6b_row14_col1, #T_a1f6b_row15_col1, #T_a1f6b_row16_col1, #T_a1f6b_row17_col1, #T_a1f6b_row18_col1, #T_a1f6b_row19_col1, #T_a1f6b_row20_col1 {
#   width: 1000px;
# }
# </style>
# <table id="T_a1f6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1f6b_level0_col0" class="col_heading level0 col0" >BrowseNotesFile</th>
#       <th id="T_a1f6b_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1f6b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1f6b_row0_col0" class="data row0 col0" >loanAmnt</td>
#       <td id="T_a1f6b_row0_col1" class="data row0 col1" >The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1f6b_row1_col0" class="data row1 col0" >annualInc</td>
#       <td id="T_a1f6b_row1_col1" class="data row1 col1" >The self-reported annual income provided by the borrower during registration.</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a1f6b_row2_col0" class="data row2 col0" >application_type</td>
#       <td id="T_a1f6b_row2_col1" class="data row2 col1" >Indicates whether the loan is an individual application or a joint application with two co-borrowers</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a1f6b_row3_col0" class="data row3 col0" >avg_cur_bal</td>
#       <td id="T_a1f6b_row3_col1" class="data row3 col1" >Average current balance of all accounts</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a1f6b_row4_col0" class="data row4 col0" >chargeoff_within_12_mths</td>
#       <td id="T_a1f6b_row4_col1" class="data row4 col1" >Number of charge-offs within 12 months</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a1f6b_row5_col0" class="data row5 col0" >delinq2Yrs</td>
#       <td id="T_a1f6b_row5_col1" class="data row5 col1" >The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a1f6b_row6_col0" class="data row6 col0" >dti</td>
#       <td id="T_a1f6b_row6_col1" class="data row6 col1" >A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a1f6b_row7_col0" class="data row7 col0" >emp_length</td>
#       <td id="T_a1f6b_row7_col1" class="data row7 col1" >Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a1f6b_row8_col0" class="data row8 col0" >grade</td>
#       <td id="T_a1f6b_row8_col1" class="data row8 col1" >LC assigned loan grade</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a1f6b_row9_col0" class="data row9 col0" >homeOwnership</td>
#       <td id="T_a1f6b_row9_col1" class="data row9 col1" >The home ownership status provided by the borrower during registration. Our values are: RENT, OWN, MORTGAGE, OTHER.</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a1f6b_row10_col0" class="data row10 col0" >inq_last_12m</td>
#       <td id="T_a1f6b_row10_col1" class="data row10 col1" >Number of credit inquiries in past 12 months</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a1f6b_row11_col0" class="data row11 col0" >installment</td>
#       <td id="T_a1f6b_row11_col1" class="data row11 col1" >The monthly payment owed by the borrower if the loan originates.</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a1f6b_row12_col0" class="data row12 col0" >job</td>
#       <td id="T_a1f6b_row12_col1" class="data row12 col1" >Job Description</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a1f6b_row13_col0" class="data row13 col0" >loanAmnt</td>
#       <td id="T_a1f6b_row13_col1" class="data row13 col1" >The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a1f6b_row14_col0" class="data row14 col0" >loanDefault</td>
#       <td id="T_a1f6b_row14_col1" class="data row14 col1" >0: Loan was uptimated paid in full. 1: A default even occurred</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a1f6b_row15_col0" class="data row15 col0" >mortAcc</td>
#       <td id="T_a1f6b_row15_col1" class="data row15 col1" >Number of mortgage accounts.</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a1f6b_row16_col0" class="data row16 col0" >num_tl_90g_dpd_24m</td>
#       <td id="T_a1f6b_row16_col1" class="data row16 col1" >Number of accounts 90 or more days past due in last 24 months</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a1f6b_row17_col0" class="data row17 col0" >pub_rec_bankruptcies</td>
#       <td id="T_a1f6b_row17_col1" class="data row17 col1" >Number of public record bankruptcies</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a1f6b_row18_col0" class="data row18 col0" >purpose</td>
#       <td id="T_a1f6b_row18_col1" class="data row18 col1" >A category provided by the borrower for the loan request. </td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a1f6b_row19_col0" class="data row19 col0" >term</td>
#       <td id="T_a1f6b_row19_col1" class="data row19 col1" >The number of payments on the loan. Values are in months and can be either 36 or 60.</td>
#     </tr>
#     <tr>
#       <th id="T_a1f6b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a1f6b_row20_col0" class="data row20 col0" >Year</td>
#       <td id="T_a1f6b_row20_col1" class="data row20 col1" >Year of Issue of the loan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Data Cleaning
#
# (The data is already pretty clean lol tho so if any of you guys wanna elaborate on it then feel free.):

# %% [markdown]
# ## Exploring the Data
#
# ### EDA steps:
# - Variable Identification
# - Univariate analysis,
# - Bi-variate analysis
# - Missing value treatment (no missing values, skip),
# - Outlier treatment (WIP),
# - Variable transformation/creation

# %% [markdown]
# ### Variable Identification

# %% [markdown]
# **Assigning variables to be categorical, ordinal, continuous and date:**
#
# ***Target Variable:***
# - loan_default
#
# ***Categorical Variables:***
# - application_type
# - home_ownership
#     - Behavioural factor
# - purpose
# - job
#     - Behavioural factor
#
# ***Ordinal Variable:***
# - grade
# - emp_length
#   - Behavioural factor
#
# ***Discrete Variables:***
# - chargeoff_within_12_mths
# - delinq_2yrs
# - inq_last_12m
# - num_actv_bc_tl
# - pub_rec_bankruptcies
# - term
#     - (36 or 60 month term)
# - mort_acc
# - num_tl_90g_dpd_24m
#
# ***Datetime Object:***
# - year
#
# ***Continous Variables:***
# - annual_inc
# - avg_cur_bal
# - dti
# - installment
# - loan_amnt

# %%
str_cats = ['application_type', 'home_ownership', 'purpose', 'job']
for cols in str_cats:
    loan[cols] = loan[cols].astype('category')

int_cats = ['chargeoff_within_12_mths', 'delinq_2yrs', 'inq_last_12m', 'num_actv_bc_tl',
            'pub_rec_bankruptcies', 'term', 'mort_acc', 'num_tl_90g_dpd_24m']
for cols in int_cats:
    loan[cols] = loan[cols].astype('int')

loan['loan_amnt'] = loan['loan_amnt'].astype('float')

# %%
def convert_to_ordinal(char):
    if char.upper() not in 'ABCDEFG':
        return None  # Return None for characters other than A to G
    return ord('G') - ord(char.upper()) + 1  # Convert the character to its reversed ordinal value

loan['grade'] = loan['grade'].apply(lambda x: convert_to_ordinal(x))

# Convert Employment into categories with similar timeframe experience
emp_len_map = {0: "< 1 year",
               1: '1 - 2 years',
               2: '1 - 2 years',
               3: '3 - 5 years',
               4: '3 - 5 years',
               5: '3 - 5 years',
               6: '6 - 9 years',
               7: '6 - 9 years',
               8: '6 - 9 years',
               9: '6 - 9 years',
               10: '10+ years'}
loan['emp_length_cat'] = loan['emp_length'].map(emp_len_map).astype('category')

emp_length_unique_list = [item for index, item in enumerate(emp_len_map.values()) if item not in list(emp_len_map.values())[:index]]

from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder(categories= [emp_length_unique_list])
loan['emp_length'] = enc.fit_transform(loan[['emp_length_cat']])
loan['emp_length'] = loan['emp_length'].astype('int')

# Remove to datetime
loan = loan.drop('year', axis= 1)

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   annual_inc                5000 non-null   float64
#  1   application_type          5000 non-null   category
#  2   avg_cur_bal               5000 non-null   float64
#  3   chargeoff_within_12_mths  5000 non-null   int64
#  4   delinq_2yrs               5000 non-null   int64
#  5   dti                       5000 non-null   float64
#  6   emp_length                5000 non-null   int64
#  7   grade                     5000 non-null   int64
#  8   inq_last_12m              5000 non-null   int64
#  9   installment               5000 non-null   float64
#  10  loan_amnt                 5000 non-null   float64
#  11  num_actv_bc_tl            5000 non-null   int64
#  12  pub_rec_bankruptcies      5000 non-null   int64
#  13  home_ownership            5000 non-null   category
#  14  term                      5000 non-null   int64
#  15  mort_acc                  5000 non-null   int64
#  16  num_tl_90g_dpd_24m        5000 non-null   int64
#  17  purpose                   5000 non-null   category
#  18  loan_default              5000 non-null   int64
#  19  job                       5000 non-null   category
#  20  emp_length_cat            5000 non-null   category
# dtypes: category(5), float64(5), int64(11)
# memory usage: 655.4 KB

# %%
# Showing the average, spread, and the range of continuous variable.
loan.describe().applymap('{:,.2f}'.format)
# Out:
#        annual_inc avg_cur_bal chargeoff_within_12_mths delinq_2yrs       dti  \
# count    5,000.00    5,000.00                 5,000.00    5,000.00  5,000.00
# mean    79,301.50   13,687.34                     0.01        0.32     18.06
# std     46,568.05   16,501.18                     0.11        0.83      8.75
# min     12,000.00        0.00                     0.00        0.00      0.00
# 25%     49,500.00    3,028.75                     0.00        0.00     11.49
# 50%     69,500.00    7,324.50                     0.00        0.00     17.26
# 75%     96,000.00   19,124.00                     0.00        0.00     24.24
# max    499,000.00  276,618.00                     3.00       12.00     49.43
#
#       emp_length     grade inq_last_12m installment  loan_amnt num_actv_bc_tl  \
# count   5,000.00  5,000.00     5,000.00    5,000.00   5,000.00       5,000.00
# mean        2.64      5.20         2.38      447.17  14,577.06           3.58
# std         1.20      1.30         2.45      282.05   9,234.44           2.33
# min         1.00      1.00         0.00       30.12   1,000.00           0.00
# 25%         2.00      4.00         1.00      240.67   7,337.50           2.00
# 50%         3.00      5.00         2.00      371.64  12,000.00           3.00
# 75%         4.00      6.00         3.00      602.30  20,000.00           5.00
# max         4.00      7.00        19.00    1,504.85  40,000.00          22.00
#
#       pub_rec_bankruptcies      term  mort_acc num_tl_90g_dpd_24m loan_default
# count             5,000.00  5,000.00  5,000.00           5,000.00     5,000.00
# mean                  0.15     41.73      1.49               0.08         0.23
# std                   0.40     10.23      1.76               0.36         0.42
# min                   0.00     36.00      0.00               0.00         0.00
# 25%                   0.00     36.00      0.00               0.00         0.00
# 50%                   0.00     36.00      1.00               0.00         0.00
# 75%                   0.00     36.00      2.00               0.00         0.00
# max                   6.00     60.00      9.00               4.00         1.00

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# Separate target variable (loan default) from feature variables. Additionally, separate numerical features from categorical features for univariate and bivariate analysis.

# %%
# separate target and feature
target = pd.DataFrame(loan["loan_default"])
feature = loan.loc[:, loan.columns != 'loan_default']

# %%
# # separate categorical, discrete and numerical features
# conts_feat = feature.select_dtypes(include=['float']).columns.tolist()
# disc_feat = feature.select_dtypes(include=['int']).columns.tolist()
# cat_feat = feature.select_dtypes(include=['category']).columns.tolist()
# numerical = feature[conts_feat]
# discrete  = feature[disc_feat]
# categorical = feature[cat_feat]
#
# numerical.shape, discrete.shape, categorical.shape

# %%
# print("\nnumerical  :", list(numerical.columns))
# print("\ndiscrete   :", list(discrete.columns))
# print("\ncategorical:", list(categorical.columns))

# %% [markdown]
# #### Target Variable

# %%
default_plot = sns.countplot(x='loan_default', data = loan)
plt.title("Loan Default")
plt.xticks(ticks=range(len([0,1])), labels=['No Default', 'Default'])
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# - We can that around 20-25 percent of all loans in the data set are defaults
# - Due to the bias towards non-defaults, we need to consider resampling our dataset to create equal amount of each category.
# - Using F1 score for deciding the success of a model would make sense.

# %% [markdown]
# #### Predictor Variables

# %% [markdown]
# ##### **Plot distributions for numerical features**

# %%
# create figure for numerical feature plots
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(10, 8))
# Iterate over each data column and plot on each subplot using a for loop

for i, (col, ax) in enumerate(zip(feature.select_dtypes(include=['float']).columns, axes.flatten())):
    mean = loan[col].mean()
    median = loan[col].median()
    var = loan[col].var().round(2)
    if var > 100000:
      var = "{:.2e}".format(var)

    ax.hist(loan[col], bins=50, color='skyblue', edgecolor='black')  # Adjust bins as needed
    ax.set_title(f"mean={mean:.3f}, median={median:.3f}, var={var}", fontweight='bold')
    ax.set_xlabel(col)

plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.8, hspace=0.4)

# %% [markdown]
# - The distributions of these variables are skewed due to their values being strictly positive.
# - Will require a log transformation on avg_cur_bal and dti.
# - We will see in later analysis that we will not require loan_amnt, and do feature engineering with installment and annual_inc which includes a log transformation.

# %%
import numpy as np
loan['avg_cur_bal_log'] = np.log(loan.avg_cur_bal + 1)
loan['dti_log'] = np.log(loan.dti + 1)

# %% [markdown]
# #### **Focus: Annual Income**

# %%
import numpy as np
import seaborn as sns

loan['annual_inc_log'] = np.log(loan.annual_inc)

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(10, 10))

# Plot histogram on the first subplot
axs[0].hist(loan['annual_inc_log'], bins=100, density=True)
axs[0].set_title("Log-Annual Income Distribution")
axs[0].set_xlabel("log(Annual Income)")

# Plot QQ plot on the second subplot
from scipy import stats
stats.probplot(loan['annual_inc_log'], dist="norm", plot=axs[1])
axs[1].set_title('QQ Plot')

plt.show()

# %% [markdown]
# - We can now see a more normally distribution of the annual income

# %% [markdown]
# ##### **Plot distributions for categorical variables**

# %%
def get_ct(df, var):
    ct_res = pd.crosstab(df[var], df['loan_default'], margins=True)
    ct_res['Defaulted(%)'] = round( ct_res[1]/ct_res['All']*100, 2)
    return ct_res.drop(columns='All')

# %% [markdown]
# This is a contigency table to see the relationship between the categorical variables.

# %% [markdown]
# **Looking at employment length (Behavioural Factor)**

# %%
mean_default_prob = loan.groupby("emp_length_cat")["loan_default"].mean().reset_index()
mean_default_prob = mean_default_prob.sort_values(by="loan_default", ascending=False)

# Create subplots
fig, (ax1, ax2) = plt.subplots(figsize=(10, 5), ncols=2, sharey= False)

# Boxplot on the first subplot
sns.boxplot(x='emp_length_cat', y='annual_inc', data=loan, showfliers=False, order= emp_length_unique_list, ax=ax1)
ax1.set_title("Annual Income vs Employment Length")
ax1.set_xlabel("Employment Length")

# Bar plot on the second subplot
sns.barplot(x='emp_length_cat', y='loan_default', data=loan , order = emp_length_unique_list, ax=ax2)
ax2.set_title("Annual Income vs Default Probability on Avg")
ax2.set_xlabel("Employment Length")
# Set y-label for the bar plot
ax2.set_ylabel("Default Probability On Avg")

# Rotate x-axis labels for better readability
ax2.tick_params(axis='x', rotation=90)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# We can see that there is an increase with employment length and their annual income. However, when taking in the average probability for defaulting, there is no clear relationship with defaulting.

# %%
get_ct(loan, 'emp_length')
# Out:
# loan_default     0     1  Defaulted(%)
# emp_length
# 1              932   290         23.73
# 2              871   255         22.65
# 3              646   215         24.97
# 4             1404   387         21.61
# All           3853  1147         22.94

# %% [markdown]
# - Interesting aspect in this situation is that there is no data for < 1 year of employment length

# %% [markdown]
# **Home Ownership (Behavioural Factor)**

# %%
fig, (ax1, ax2) = plt.subplots(figsize = (10,5), ncols=2, sharey= False)
sns.boxplot(x="home_ownership",y="annual_inc", data = loan, showfliers=False, ax = ax1) #showfliers=False for nice display
ax1.set_title("Home ownership vs. annual income")
loan[["home_ownership",'loan_default']].groupby("home_ownership").mean().plot.bar(rot=90,ax = ax2)
plt.title("Default probability vs. home ownership on Avg");

# Adjust layout
plt.tight_layout()

# %% [markdown]
# - As suspected, annual income for people who rent tend to be lower than people who own or take a mortgage, and their probabilility of defaulting is the highest.
# - This could play as a beneficial factor when determining a behavioural factor for deciding our model.

# %%
get_ct(loan, 'home_ownership')
# Out:
# loan_default       0     1  Defaulted(%)
# home_ownership
# MORTGAGE        1945   479         19.76
# OWN              466   136         22.59
# RENT            1442   532         26.95
# All             3853  1147         22.94

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# #### **Marginal distribution of Default Status based on Log-Annual Income**

# %%
loan['annual_inc_log'][loan.loan_default == 0].hist(bins=50, density=True, alpha=0.5, label="Paid")
loan['annual_inc_log'][loan.loan_default == 1].hist(bins=50, density=True, alpha=0.5, label="Default")
plt.xlabel("log-Annual Income")
plt.legend()
plt.title("Annual Income -- Loan Status", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Annual Income -- Loan Status')

# %% [markdown]
# - We can see that the distribution for both the groups in terms of their annual income are similarly distributed.
# - This can indicate that income is not likely to explain the difference in loan status.

# %% [markdown]
# #### **Annual Income & Monthly Installments**

# %%
sns.jointplot(data = loan, x = 'installment', y = 'annual_inc_log', kind="hex")

# %% [markdown]
# - As mentioned previously, the installment predictor is skewed positively. We will need it to undergo a log transformation

# %%
sns.jointplot(data = loan, x = np.log(loan.installment), y = 'annual_inc_log', kind="hex")

# %% [markdown]
# - We can see that there is a more linear relationship between these 2 variables, with a few outliers on the far left.

# %%
# Create a correlation plot to see how each pair of variables relate to one another.
# Compute the correlation matrix.
corr_matrix = loan[feature.select_dtypes(include=['float']).columns].corr()
# Create a mask to hide the upper triangle of our corrplot
mask = np.triu(np.ones_like(corr_matrix))

# Plotting the heatmap for correlation.
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', mask = mask, ax=axes[0])
sns.regplot(x = 'installment', y = 'loan_amnt', data = loan, ax=axes[1])

# Set titles
axes[0].set_title('Correlation Plot')
axes[1].set_title('Installment vs Loan Amount with Regression Line')

axes[1].set_xlabel('installment')
axes[1].set_ylabel('loan_amnt')

# Adjust layout
plt.tight_layout()

# Show plots
plt.show()

# %% [markdown]
# Correlation is huge for "installment" and "loan_amnt", which means the monthly payment owed by the borrower and the listed amount of the loan applied for by the borrower has a strong correlation. This is reasonable given a borrower needs to pay back more per month their debt back if the debt amount is huge.
#
# Since "installment" and "loan amount" are so closely related, we need to check if they have a linear relationship. If colinearity exists, then we should ignore one of them.
#
# For this analysis we will drop the loan_amnt variable as installment will play a major role as a factor in our hypothesis.

# %%
loan = loan.drop('loan_amnt', axis = 1)

# %% [markdown]
# ### Missing Values Treatment

# %%
#Missing value treatment
# checking missing values
loan.isnull().sum()
# Out:
# annual_inc                  0
# application_type            0
# avg_cur_bal                 0
# chargeoff_within_12_mths    0
# delinq_2yrs                 0
# dti                         0
# emp_length                  0
# grade                       0
# inq_last_12m                0
# installment                 0
# num_actv_bc_tl              0
# pub_rec_bankruptcies        0
# home_ownership              0
# term                        0
# mort_acc                    0
# num_tl_90g_dpd_24m          0
# purpose                     0
# loan_default                0
# job                         0
# emp_length_cat              0
# avg_cur_bal_log             0
# dti_log                     0
# annual_inc_log              0
# dtype: int64

# %% [markdown]
# There are no missing values in any of our variables.

# %% [markdown]
# ### Outlier Treatment

# %%
def outlier_check(column):
  # Specify the numerical columns for outlier detection
  numerical_columns = loan.select_dtypes(include=['float64']).columns

  # Calculate the IQR for each numerical column
  Q1 = column.quantile(0.25)
  Q3 = column.quantile(0.75)
  IQR = Q3 - Q1

  # Identify outliers
  outliers = ((loan[numerical_columns] < (Q1 - 1.5 * IQR)) | (loan[numerical_columns] > (Q3 + 1.5 * IQR))).any(axis=1)
  #return outliers[outliers == True]
  return loan[outliers]

# Generate a list of numerical columns
numerical_columns = loan.select_dtypes(include=['float64']).columns

# Calculate an array of IQR for each numerical column
Q1 = loan[numerical_columns].quantile(0.25)
Q3 = loan[numerical_columns].quantile(0.75)
IQR = Q3 - Q1

# Identify outliers
outliers = ((loan[numerical_columns] < (Q1 - 1.5 * IQR)) | (loan[numerical_columns] > (Q3 + 1.5 * IQR))).any(axis=1)

# Display the outliers
loan[outliers][numerical_columns]
# Out:
#       annual_inc  avg_cur_bal    dti  installment  avg_cur_bal_log   dti_log  \
# 12       75000.0        742.0   1.22       542.07         6.610696  0.797507
# 34       79000.0       4088.0  22.14      1327.45         8.316056  3.141563
# 35       52000.0      51655.0  15.94       184.35        10.852362  2.829678
# 38      185000.0      21735.0   4.09       402.08         9.986725  1.627278
# 39      400000.0      64556.0  10.07      1174.91        11.075304  2.404239
# ...          ...          ...    ...          ...              ...       ...
# 4948     96000.0      91931.0   8.24       285.71        11.428804  2.223542
# 4950    173000.0      20760.0  28.22       287.44         9.940832  3.374853
# 4959     15000.0       1960.0  34.86       171.11         7.581210  3.579622
# 4962     85000.0      44945.0  13.53       125.30        10.713217  2.676215
# 4995     90000.0      47759.0  15.88        49.46        10.773944  2.826129
#
#       annual_inc_log
# 12         11.225243
# 34         11.277203
# 35         10.858999
# 38         12.128111
# 39         12.899220
# ...              ...
# 4948       11.472103
# 4950       12.061047
# 4959        9.615805
# 4962       11.350407
# 4995       11.407565
#
# [737 rows x 7 columns]

# %% [markdown]
# - As we can see there are about 621 data points that contain outlier data.
# - For now we will leave the data how it is, and in the future decide what best to do with these outliers.

# %% [markdown]
# ### Variable Transformation/Creation

# %% [markdown]
# #### **Yearly Installment Income**
#
# - The yearly paymnt owed by the borrower, as a fraction of annual income, is a standard metric used in evaluating whether a loan should be issued.
# - We create a new variable that calculates this using the installment variable and annual income

# %%
loan['install_income'] = 12 * loan.installment / loan.annual_inc
H = plt.hist(loan['install_income'], bins=200, density=True)
plt.xlabel(r"Installment / Income")
# Out:
# Text(0.5, 0, 'Installment / Income')

# %% [markdown]
# - Quite clearly, we see the distribution is positively skewed, it will need a transformation when we would like to test for significance.

# %%
# let us discretize the "install_income" variable to study the probability of default
# as a function of "install_income"
loan["install_income_disc"] = (loan.install_income*50).astype(int)/50.  #discretization
loan[["loan_default", "install_income_disc"]].groupby("install_income_disc").mean().plot.bar(rot=90)
loan = loan.drop(["install_income_disc"], axis=1)

# %% [markdown]
# - There is a clear positive association: as the fraction of the annual income devoted to the re-imbursement of the loan increases, the probability of default sharply increases

# %%
# Here we are going to transform our new variable using the box cox method in order for it to be normally distributed. Reason for using box cox method was to avoid using log transformation due to the values being between 0 and 0.5 due to it being a ratio.
from scipy.stats import boxcox
from sklearn.preprocessing import MinMaxScaler
transformed_data, _ = boxcox(loan['install_income'] + 1)
# Scale the transformed data to range [0, 1]
scaler = MinMaxScaler(feature_range=(0, 1))
transformed_data_scaled = scaler.fit_transform(transformed_data.reshape(-1, 1)).flatten()

# Plot histograms of original and transformed data
plt.figure(figsize=(10, 5))

plt.subplot(1, 3, 1)
plt.hist(loan.install_income, bins=20, color='blue', alpha=0.5, density= True)
plt.title('Install Income \nOriginal')
plt.xlabel('Values')

plt.subplot(1, 3, 2)
plt.hist(transformed_data_scaled, bins=20, color='red', alpha=0.5)
plt.title('Install Income \nBox Cox Transform')
plt.xlabel('Values')

plt.subplot(1, 3, 3)
stats.probplot(transformed_data_scaled, dist="norm", plot= plt)
plt.title("Install Income\n Box Cox Transform")

# Adjust layout
plt.tight_layout()

plt.show()

# Adding this variable to our loan data
loan['install_income_norm'] = transformed_data_scaled

# %% [markdown]
# We want to assess whether there is a signficance of the install_income with respect to loan_default parameter using the t test.

# %% [markdown]
# $ \mu_1$ is the mean of install income given that they have not defaulted
# $ \mu_2$ is the mean of install income given that they have defaulted
# $$ H_0: \mu_1=\mu_2$$
# $$H_a: \mu_1 \neq \mu_2$$

# %%
from scipy.stats import ttest_ind
binary_categorical_variable = loan['loan_default']
transformed_data = loan['install_income_norm']

# Perform t-test for independent samples
t_statistic, p_value = ttest_ind(transformed_data[binary_categorical_variable == 0],
                                  transformed_data[binary_categorical_variable == 1])

# Print the results
print("T-statistic:", t_statistic)
print("P-value:", p_value)
# Out:
# T-statistic: -12.482459955482879
# P-value: 3.105367751892538e-35

# %% [markdown]
# Based on the statistical test above, we can **reject the null hypothesis**. We can definitely see there is huge difference in means resulting in high correlation between them.

# %% [markdown]
# #### Categorical Variables Dummy Creation & Ordinal Variable (employment length)
#
# Recall our categorical variables:
# - application_type
# - home_ownership
#     - Behavioural factor
# - purpose
# - job
#     - Behavioural factor
#
# We might have issues when looking at job and purpose as a categorical variable due to how many unique items there are.
#
# Approaches:
#
# 1. For Purpose, we can check the frequency of each purpose and determine whether we can bin these to another categorical variable.
# 2. For Job, it is best to creating some level of discrete values in one column. We do this by looking at the count of each variable and then setting it as the value.
#
# Advantages:
# 1. It is very simple to implement
# 2. Does not increase the feature dimensional space
#
# Disadvantages:
# 1. If some labels have the same count, then they will be replaced with the same count and they will loose some valuable information.
# 2. Adds somewhat arbitrary numbers, and therefore weights to the different labels, that may not be related to their predictive power.

# %% [markdown]
# ##### Loan Purpose

# %%
plt.figure(figsize= (15,5))
purp = loan['purpose']
ax = sns.barplot(x=list(purp.value_counts().index.values),
            y=100 * purp.value_counts().values / len(purp),
            orient="v",
            )

counts = purp.value_counts()
total_obs = len(purp)
percentage = (counts / total_obs) * 100
percentages_sorted = percentage.sort_values(ascending=False)

for i, percentage in enumerate(percentages_sorted):
    ax.text(i, percentage + 0.5, f"{percentage:.2f}%", ha='center', va='bottom')

plt.xticks(rotation=90)
plt.ylabel("Percentage of Population")
plt.title("Distribution of Loan Purposes", fontsize=20);

# %%
plt.figure(figsize= (15,10))
unstacked_df = loan.groupby(['purpose', 'loan_default']).size().unstack()
unstacked_df[0] = unstacked_df[0] / len(loan) *100
unstacked_df[1] = unstacked_df[1] / len(loan) *100
sorted_df = unstacked_df.sum(axis=1).sort_values(ascending=False).index

plt.figure(figsize=(10, 6))
unstacked_df.loc[sorted_df].plot(kind='bar', stacked=True)
plt.title('Distribution of Loan Purposes vs Loan Default Percentages')
plt.xlabel('Loan Purposes')
plt.ylabel('Count %')
plt.xticks(rotation=90)
plt.legend(title='Loan Default', labels=['Non-Default', 'Default'])
plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the above plot, we can see that most of the data belongs to debt_consolidation. I would reccomend that we reduce the dimensionality by anything below 2% of the sample population be joined into the other category.

# %%
# Loop through the DataFrame and rename loan purposes
for i, purpose in enumerate(loan['purpose']):
    if purpose in list(purp.value_counts().index.values[5:]):
        loan.at[i, 'purpose'] == 'other'
    elif purpose == 'credit_card':
        loan.at[i, 'purpose'] == 'other'

loan['purpose'] = pd.Categorical(loan['purpose'],
                                        categories= ['debt_consolidation', 'credit_card', 'home_improvement', 'other', 'major_purchase'],
                                        ordered = False)
plt.figure(figsize= (15,5))
cat = loan['purpose']
ax = sns.barplot(x=list(cat.value_counts().index.values),
                 y=100 * cat.value_counts().values / len(loan),
                 orient="v",
                 )

counts = cat.value_counts()
total_obs = len(cat)
percentage = (counts / total_obs) * 100
percentages_sorted = percentage.sort_values(ascending=False)

for i, percentage in enumerate(percentages_sorted):
    ax.text(i, percentage + 0.5, f"{percentage:.2f}%", ha='center', va='bottom')

plt.xticks(rotation=90)
plt.ylabel("Percentage of Population")
plt.title("Distribution of Loan Purposes", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of Loan Purposes')

# %%
plt.figure(figsize= (15,10))
unstacked_df = loan.groupby(['purpose', 'loan_default']).size().unstack()
unstacked_df[0] = unstacked_df[0] / len(loan) *100
unstacked_df[1] = unstacked_df[1] / len(loan) *100
sorted_df = unstacked_df.sum(axis=1).sort_values(ascending=False).index

plt.figure(figsize=(10, 6))
unstacked_df.loc[sorted_df].plot(kind='bar', stacked=True)
plt.title('Distribution of Loan Purposes vs Loan Default Percentages')
plt.xlabel('Loan Purposes')
plt.ylabel('Count %')
plt.xticks(rotation=90)
plt.legend(title='Loan Default', labels=['Non-Default', 'Default'])
plt.tight_layout()
plt.show()

# %%
# # Loop through the DataFrame and rename loan purposes
# for i, purpose in enumerate(categorical['purpose']):
#     if purpose in list(purp.value_counts().index.values[5:]):
#         categorical.at[i, 'purpose'] = 'other'
#     elif purpose is 'credit_card':
#         categorical.at[i, 'purpose'] = 'other'
#
# categorical['purpose'] = pd.Categorical(categorical['purpose'],
#                                         categories= ['debt_consolidation', 'other'],
#                                         ordered = False)
# plt.figure(figsize= (15,5))
# cat = categorical['purpose']
# ax = sns.barplot(x=list(cat.value_counts().index.values),
#                  y=100 * cat.value_counts().values / len(categorical),
#                  orient="v",
#                  )
#
# counts = cat.value_counts()
# total_obs = len(cat)
# percentage = (counts / total_obs) * 100
# percentages_sorted = percentage.sort_values(ascending=False)
#
# for i, percentage in enumerate(percentages_sorted):
#     ax.text(i, percentage + 0.5, f"{percentage:.2f}%", ha='center', va='bottom')
#
# plt.xticks(rotation=90)
# plt.ylabel("Percentage of Population")
# plt.title("Distribution of Loan Purposes", fontsize=20);

# %% [markdown]
# ##### Job (Behavioral Factor)

# %%
plt.figure(figsize= (15,5))
ax = sns.barplot(x=list(loan["job"].value_counts()[:10].index.values),
            y=100 * loan.job.value_counts()[:10].values / len(loan),
            orient="v",
            )

counts = loan['job'].value_counts()[:10]
total_obs = len(loan['job'])
percentage = (counts / total_obs) * 100
percentages_sorted = percentage.sort_values(ascending=False)

for i, percentage in enumerate(percentages_sorted):
    ax.text(i, percentage + 0.5, f"{percentage:.2f}%", ha='center', va='bottom')

plt.xticks(rotation=90)
plt.ylabel("Percentage of Population")
plt.title("Distribution of Jobs (Top 10) ", fontsize=20);

# %%
print("Distinct Jobs in Dataset: ", loan['job'].nunique())
# Out:
# Distinct Jobs in Dataset:  119

# %% [markdown]
# Since we have 119 various distinct jobs in our dataset, we can consider consolidating them into major industry sectors:
# 1. Science_Tech
# 2. Healthcare
# 3. Finance & Banking
# 4. Education
# 5. Manufacturing
# 6. Retail
# 7. Hospitality & Tourism
# 8. Construction
# 9. Transportation
# 10. Law
# 11. Administration
# 12. Maintenance
# 13. Public Safety
# 14. Business Executives
# 15. Other

# %%
Science_Tech = ['it', 'programmer', 'support', 'tech', 'technologist', 'engineer', 'scientist']
HealthCare = ['examiner', 'hygienist', 'nurse', 'paramedic', 'pharmacist', 'physician', 'practitioner', 'therapist', 'trainer']
Finance_Banking = ['accountant', 'accounting', 'adjuster', 'auditor', 'banker', 'bookkeeper', 'finance', 'sales', 'teller', 'underwriter']
Education = ['educator', 'instructor','professor', 'teacher', 'principal']
Manufacturing = ['operations', 'warehouse', 'welder']
Retail = ['cashier']
Hospitality_Tourism = ['bartender', 'chef', 'cook', 'server', 'service', 'services']
Construction = ['architect', 'carpenter', 'controller', 'developer', 'foreman', 'laborer', 'machinist']
Transportation = ['carrier', 'driver']
Law = ['attorney', 'consultant', 'paralegal']
Administration = ['administration', 'admin', 'clerk', 'management', 'manager', 'manger', 'receptionist', 'recruiter', 'resources', 'secretary', 'supervisor', 'assistant']
Maintenance = ['custodian', 'electrician', 'installer', 'maintenance', 'painter', 'technician']
Public_Safety = ['firefighter', 'investigator', 'officer', 'security', 'sergeant', 'superintendent', 'chief','dispatcher' ]
Business_Management = ['partner', 'ceo', 'director', 'executive', 'president', 'vp']
Other = ['advisor', 'agent', 'aide', 'analyst', 'associate', 'attendant','broker','buyer','captain', 'coach', 'coordinator', 'counselor', 'dealer','designer','estimator', 'handler', 'inspector', 'lead','leader', 'marketing', 'operator', 'other', 'owner', 'pastor', 'planner', 'realtor', 'representative','specialist', 'worker' ]

sector_job_mapping = {'sci_tech': Science_Tech,
              'finance_bank': Finance_Banking,
              'education': Education,
              'manufacture': Manufacturing,
              'retail': Retail,
              'hospitalitty_tourism': Hospitality_Tourism,
              'construction': Construction,
              'transport': Transportation,
              'law': Law,
              'admin': Administration,
              'maintenance': Maintenance,
              'public_safety': Public_Safety,
              'business_execs': Business_Management,
              'other': Other}

def map_job_to_sector(job):
    for sector, jobs in sector_job_mapping.items():
        if job in jobs:
            return sector
    return 'other'  # Assign 'Other' if job does not match any sector

loan['job_sector'] = loan['job'].apply(map_job_to_sector)

print("Distinct Jobs in Dataset: ", loan['job_sector'].nunique())
# Out:
# Distinct Jobs in Dataset:  14

# %% [markdown]
# As we can see with the above output, we have now reduced it by major sectors to 15.

# %%
plt.figure(figsize= (15,5))
ax = sns.barplot(x=list(loan["job_sector"].value_counts()[:15].index.values),
                 y=100 * loan.job_sector.value_counts()[:15].values / len(loan),
                 orient="v",
                 )

counts = loan['job_sector'].value_counts()[:15]
total_obs = len(loan['job_sector'])
percentage = (counts / total_obs) * 100
percentages_sorted = percentage.sort_values(ascending=False)

for i, percentage in enumerate(percentages_sorted):
    ax.text(i, percentage + 0.5, f"{percentage:.2f}%", ha='center', va='bottom')

plt.xticks(rotation=90)
plt.ylabel("Percentage of Population")
plt.title("Distribution of Job Sectors", fontsize=20);

# %%
# Create and Update to categorical data
cat_job              = pd.get_dummies(loan['job_sector'], prefix= 'jobSector', drop_first= True)
cat_purpose          = pd.get_dummies(loan['purpose'], prefix= 'purpose', drop_first= True)
cat_application_type = pd.get_dummies(loan['application_type'], prefix= 'app_type', drop_first= True)
cat_home_ownership   = pd.get_dummies(loan['home_ownership'], prefix= 'home_own', drop_first= True)
loan = pd.concat([loan, cat_purpose], axis= 1)
loan = pd.concat([loan, cat_application_type], axis= 1)
loan = pd.concat([loan, cat_home_ownership], axis= 1)
loan = pd.concat([loan, cat_job], axis = 1)

# Remove unnecessary variables, that will not be used for the model
loan2 = loan.drop(['purpose',
                   'application_type',
                   'home_ownership',
                   'emp_length_cat',
                   'annual_inc',
                   'annual_inc_log',
                   'installment',
                   'install_income',
                   'avg_cur_bal',
                   'dti',
                   'job',
                   'job_sector'], axis = 1)

# %%
loan2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   chargeoff_within_12_mths        5000 non-null   int64
#  1   delinq_2yrs                     5000 non-null   int64
#  2   emp_length                      5000 non-null   int64
#  3   grade                           5000 non-null   int64
#  4   inq_last_12m                    5000 non-null   int64
#  5   num_actv_bc_tl                  5000 non-null   int64
#  6   pub_rec_bankruptcies            5000 non-null   int64
#  7   term                            5000 non-null   int64
#  8   mort_acc                        5000 non-null   int64
#  9   num_tl_90g_dpd_24m              5000 non-null   int64
#  10  loan_default                    5000 non-null   int64
#  11  avg_cur_bal_log                 5000 non-null   float64
#  12  dti_log                         5000 non-null   float64
#  13  install_income_norm             5000 non-null   float64
#  14  purpose_credit_card             5000 non-null   uint8
#  15  purpose_home_improvement        5000 non-null   uint8
#  16  purpose_other                   5000 non-null   uint8
#  17  purpose_major_purchase          5000 non-null   uint8
#  18  app_type_Joint App              5000 non-null   uint8
#  19  home_own_OWN                    5000 non-null   uint8
#  20  home_own_RENT                   5000 non-null   uint8
#  21  jobSector_business_execs        5000 non-null   uint8
#  22  jobSector_construction          5000 non-null   uint8
#  23  jobSector_education             5000 non-null   uint8
#  24  jobSector_finance_bank          5000 non-null   uint8
#  25  jobSector_hospitalitty_tourism  5000 non-null   uint8
#  26  jobSector_law                   5000 non-null   uint8
#  27  jobSector_maintenance           5000 non-null   uint8
#  28  jobSector_manufacture           5000 non-null   uint8
#  29  jobSector_other                 5000 non-null   uint8
#  30  jobSector_public_safety         5000 non-null   uint8
#  31  jobSector_retail                5000 non-null   uint8
#  32  jobSector_sci_tech              5000 non-null   uint8
#  33  jobSector_transport             5000 non-null   uint8
# dtypes: float64(3), int64(11), uint8(20)
# memory usage: 644.7 KB

# %%
loan2.head()
# Out:
#    chargeoff_within_12_mths  delinq_2yrs  emp_length  grade  inq_last_12m  \
# 0                         0            0           4      6             1
# 1                         0            0           3      4             0
# 2                         0            0           1      4             6
# 3                         0            0           3      4             7
# 4                         0            0           4      4             0
#
#    num_actv_bc_tl  pub_rec_bankruptcies  term  mort_acc  num_tl_90g_dpd_24m  \
# 0               1                     0    36         0                   0
# 1               3                     0    60         1                   0
# 2               4                     0    60         3                   0
# 3               2                     0    36         4                   0
# 4               4                     0    36         0                   0
#
#    ...  jobSector_finance_bank  jobSector_hospitalitty_tourism  jobSector_law  \
# 0  ...                       0                               0              0
# 1  ...                       0                               0              0
# 2  ...                       0                               0              0
# 3  ...                       0                               0              0
# 4  ...                       0                               0              0
#
#    jobSector_maintenance  jobSector_manufacture  jobSector_other  \
# 0                      0                      0                0
# 1                      0                      0                1
# 2                      0                      0                1
# 3                      0                      0                1
# 4                      0                      0                0
#
#    jobSector_public_safety  jobSector_retail  jobSector_sci_tech  \
# 0                        0                 0                   0
# 1                        0                 0                   0
# 2                        0                 0                   0
# 3                        0                 0                   0
# 4                        0                 0                   0
#
#    jobSector_transport
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    1
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Re-Sampling Technique

# %%
df = loan2.copy()
print('Loan Default class percentages:')
class_percentage = df['loan_default'].value_counts(normalize=True) * 100
print(class_percentage)
print(df.loan_default.value_counts())
# Out:
# Loan Default class percentages:
# 0    77.06
# 1    22.94
# Name: loan_default, dtype: float64
# 0    3853
# 1    1147
# Name: loan_default, dtype: int64

# %%
X = df.drop(columns='loan_default', axis = 1)
Y = df[['loan_default']]

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state= 1)

X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((3750, 33), (3750, 1), (1250, 33), (1250, 1))

# %%
# Building a logistic model to test the up-sampling
def logModel_testing(X_train, Y_train, X_test, Y_test):
    from sklearn.linear_model import LogisticRegression
    logistic_model = LogisticRegression(penalty='l2', C=1.0, solver='liblinear').fit(X_train,Y_train)
    y_pred = logistic_model.predict(X_test)

    # Print Summary of Model
    from statsmodels.api import Logit

    # Use statsmodels to print summary
    logit_model = Logit(Y_train, X_train)
    result = logit_model.fit()
    # print(result.summary())
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import ConfusionMatrixDisplay

    cf_matrix=confusion_matrix(y_pred,Y_test)
    TN = cf_matrix[0, 0]
    FP = cf_matrix[0, 1]
    FN = cf_matrix[1, 0]
    TP = cf_matrix[1, 1]

    # Classification Metrics
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import precision_score
    from sklearn.metrics import recall_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import classification_report
    acc = accuracy_score(Y_test, y_pred)
    prec = precision_score(Y_test, y_pred)
    recall = recall_score(Y_test, y_pred)
    f1 = f1_score(Y_test, y_pred)
    error_rate = (FP + FN)/ (TP + TN + FP)
    print("accuracy_score : ", acc)
    print("precision_score : ", prec)
    print("recall_score : ", recall)
    print("f1_score : ", f1)
    print("error rate: ", error_rate)
    target_names = ['class 0', 'class 1']
    print(classification_report(Y_test, y_pred, target_names=target_names))

    dis = ConfusionMatrixDisplay(confusion_matrix= cf_matrix )
    dis.plot(cmap=plt.cm.Blues)
    plt.show()

# %% [markdown]
# #### Without Any Resampling

# %%
logModel_testing(X_train, Y_train, X_test, Y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Optimization terminated successfully.
#          Current function value: 0.479966
#          Iterations 6
# accuracy_score :  0.7536
# precision_score :  0.4918032786885246
# recall_score :  0.09771986970684039
# f1_score :  0.16304347826086957
# error rate:  0.2526661197703035
#               precision    recall  f1-score   support
#
#      class 0       0.77      0.97      0.86       943
#      class 1       0.49      0.10      0.16       307
#
#     accuracy                           0.75      1250
#    macro avg       0.63      0.53      0.51      1250
# weighted avg       0.70      0.75      0.69      1250

# %% [markdown]
# ### Method 1: Up and Down Sampling

# %%
df_train = pd.concat([X_train, Y_train], axis = 1)
df_majority = df_train[df_train['loan_default']==0]
df_minority = df_train[df_train['loan_default']==1]

# %% [markdown]
# #### UP Sampling

# %%
# Separating majority and minority for Loan Default (dependent var.)
from sklearn.utils import resample
df_minority_upsampled = resample(df_minority,
                                 replace= True,
                                 n_samples= len(df_majority),
                                 random_state= 1)
df_upsampled = pd.concat([df_majority, df_minority_upsampled])
df_upsampled = df_upsampled.sample(frac = 1) # Reshuffling our training data

# Dividing training with target variable and predictors
X_train = df_upsampled.drop('loan_default', axis=1)
Y_train = df_upsampled[['loan_default']]

resampling_type = "Up Sampled"

print("Shape of Data ({}):".format(resampling_type))
print(df_upsampled.shape)

print("\nShape of our Testing Training Data ({}): ".format(resampling_type))
print("Train:", "X = ", X_train.shape  , "Y = ", Y_train.shape)
print("Test :", "X = ", X_test.shape, "Y = ", Y_test.shape)

print('\nLoan Default class percentages ({}):'.format(resampling_type))
class_percentage = df_upsampled['loan_default'].value_counts(normalize=True) * 100
print(class_percentage)
print(df_upsampled.loan_default.value_counts())
# Out:
# Shape of Data (Up Sampled):
# (5820, 34)
#
# Shape of our Testing Training Data (Up Sampled):
# Train: X =  (5820, 33) Y =  (5820, 1)
# Test : X =  (1250, 33) Y =  (1250, 1)
#
# Loan Default class percentages (Up Sampled):
# 1    50.0
# 0    50.0
# Name: loan_default, dtype: float64
# 1    2910
# 0    2910
# Name: loan_default, dtype: int64

# %%
logModel_testing(X_train, Y_train, X_test, Y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Optimization terminated successfully.
#          Current function value: 0.617843
#          Iterations 5
# accuracy_score :  0.6752
# precision_score :  0.39622641509433965
# recall_score :  0.6156351791530945
# f1_score :  0.4821428571428572
# error rate:  0.42203742203742206
#               precision    recall  f1-score   support
#
#      class 0       0.85      0.69      0.76       943
#      class 1       0.40      0.62      0.48       307
#
#     accuracy                           0.68      1250
#    macro avg       0.62      0.66      0.62      1250
# weighted avg       0.74      0.68      0.69      1250

# %% [markdown]
# A drop in our accuracy however we do increase our f1 score compared to not re-sampling score.

# %% [markdown]
# #### DOWN Sampling

# %%
df_majority_downsampled = resample(df_majority,
                                   replace=True,    # sample without replacement
                                   n_samples = len(df_minority),     # to match minority class
                                   random_state=123) # reproducible results

df_downsampled = pd.concat([df_majority_downsampled, df_minority])
df_downsampled = df_downsampled.sample(frac=1)

# Dividing training with target variable and predictors
X_train = df_downsampled.drop('loan_default', axis=1)
Y_train = df_downsampled[['loan_default']]

resampling_type = "Down Sampled"

print("Shape of Data ({}):".format(resampling_type))
print(df_downsampled.shape)

print("\nShape of our Testing Training Data ({}): ".format(resampling_type))
print("Train:", "X = ", X_train.shape  , "Y = ", Y_train.shape)
print("Test :", "X = ", X_test.shape, "Y = ", Y_test.shape)

print('\nLoan Default class percentages ({}):'.format(resampling_type))
class_percentage = df_downsampled['loan_default'].value_counts(normalize=True) * 100
print(class_percentage)
print(df_upsampled.loan_default.value_counts())
# Out:
# Shape of Data (Down Sampled):
# (1680, 34)
#
# Shape of our Testing Training Data (Down Sampled):
# Train: X =  (1680, 33) Y =  (1680, 1)
# Test : X =  (1250, 33) Y =  (1250, 1)
#
# Loan Default class percentages (Down Sampled):
# 0    50.0
# 1    50.0
# Name: loan_default, dtype: float64
# 1    2910
# 0    2910
# Name: loan_default, dtype: int64

# %%
logModel_testing(X_train, Y_train, X_test, Y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Optimization terminated successfully.
#          Current function value: 0.612676
#          Iterations 5
# accuracy_score :  0.6768
# precision_score :  0.3991683991683992
# recall_score :  0.6254071661237784
# f1_score :  0.4873096446700508
# error rate:  0.42039542143600417
#               precision    recall  f1-score   support
#
#      class 0       0.85      0.69      0.76       943
#      class 1       0.40      0.63      0.49       307
#
#     accuracy                           0.68      1250
#    macro avg       0.62      0.66      0.63      1250
# weighted avg       0.74      0.68      0.70      1250

# %% [markdown]
# We do lose a bit of our accuracy score, however our f1 score does increase compared to not re-sampling. We also notice that the f1 score improves compared to up sampling.

# %% [markdown]
# ### Method 2: SMOTE

# %%
X_train_smote = df_train.drop('loan_default', axis=1)
Y_train_smote = df_train['loan_default']


from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=2)
X_train_res, Y_train_res = smote.fit_resample(X_train_smote, Y_train_smote.ravel())

print(X_train_res.shape, Y_train_res.shape)
print("loan_default is 0:", len(Y_train_res[Y_train_res==0]), "\nloan_default is 1:", len(Y_train_res[Y_train_res==1]))

df_train_smote = pd.concat([pd.DataFrame(X_train_res), pd.DataFrame(Y_train_res)], axis= 1)
# Out:
# (5820, 33) (5820,)
# loan_default is 0: 2910
# loan_default is 1: 2910

# %%
logModel_testing(X_train_res, Y_train_res, X_test, Y_test)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.529314
#          Iterations 6
# accuracy_score :  0.6816
# precision_score :  0.37669376693766937
# recall_score :  0.4527687296416938
# f1_score :  0.4112426035502959
# error rate:  0.39019607843137255
#               precision    recall  f1-score   support
#
#      class 0       0.81      0.76      0.78       943
#      class 1       0.38      0.45      0.41       307
#
#     accuracy                           0.68      1250
#    macro avg       0.59      0.60      0.60      1250
# weighted avg       0.70      0.68      0.69      1250

# %% [markdown]
# Accuracy is once again reduced from our non re-sampling model. We can also note that the f1 score has done worse that up sampling and down sampling. However we can see that our error rate has decreased as compared to up and down sampling.

# %% [markdown]
# ### Method 3: ADASYN

# %%
X_train_adasyn = df_train.drop('loan_default', axis=1)
Y_train_adasyn = df_train['loan_default']

from imblearn.over_sampling import ADASYN
adasyn = ADASYN(random_state=2)
X_train_res, Y_train_res = adasyn.fit_resample(X_train_adasyn, Y_train_adasyn.ravel())

print(X_train_res.shape, Y_train_res.shape)
print("loan_default is 0:", len(Y_train_res[Y_train_res==0]), "\nloan_default is 1:", len(Y_train_res[Y_train_res==1]))

df_train_adasyn = pd.concat([pd.DataFrame(X_train_res), pd.DataFrame(Y_train_res)], axis= 1)
# Out:
# (5773, 33) (5773,)
# loan_default is 0: 2910
# loan_default is 1: 2863

# %%
logModel_testing(X_train_res, Y_train_res, X_test, Y_test)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.541135
#          Iterations 6
# accuracy_score :  0.6768
# precision_score :  0.3685636856368564
# recall_score :  0.44299674267100975
# f1_score :  0.40236686390532544
# error rate:  0.3972468043264503
#               precision    recall  f1-score   support
#
#      class 0       0.81      0.75      0.78       943
#      class 1       0.37      0.44      0.40       307
#
#     accuracy                           0.68      1250
#    macro avg       0.59      0.60      0.59      1250
# weighted avg       0.70      0.68      0.69      1250

# %% [markdown]
# So far this has the best accuracy out of all the re-sampling techniques. However in terms of our f1 score, this performs the worst.

# %% [markdown]
# ### Method 4: SMOTE & ENN

# %%
X_train_se = df_train.drop('loan_default', axis=1)
Y_train_se = df_train['loan_default']

from imblearn.combine import SMOTEENN
smoteenn = SMOTEENN(random_state=2)
X_train_res, Y_train_res = adasyn.fit_resample(X_train_se, Y_train_se.ravel())

print(X_train_res.shape, Y_train_res.shape)
print("loan_default is 0:", len(Y_train_res[Y_train_res==0]), "\nloan_default is 1:", len(Y_train_res[Y_train_res==1]))

df_train_se = pd.concat([pd.DataFrame(X_train_res), pd.DataFrame(Y_train_res)], axis= 1)
# Out:
# (5773, 33) (5773,)
# loan_default is 0: 2910
# loan_default is 1: 2863

# %%
logModel_testing(X_train_res, Y_train_res, X_test, Y_test)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.541135
#          Iterations 6
# accuracy_score :  0.6768
# precision_score :  0.3685636856368564
# recall_score :  0.44299674267100975
# f1_score :  0.40236686390532544
# error rate:  0.3972468043264503
#               precision    recall  f1-score   support
#
#      class 0       0.81      0.75      0.78       943
#      class 1       0.37      0.44      0.40       307
#
#     accuracy                           0.68      1250
#    macro avg       0.59      0.60      0.59      1250
# weighted avg       0.70      0.68      0.69      1250

# %% [markdown]
# We get similar results to our ADASYN re-sampling technique

# %% [markdown]
# #### RESULTS FROM THE RESAMPLING:
#
# | Resampling Technique |Loan Default Metric|        |          | Overall Model                                  |
# |                      | Precision         | Recall | F1 Score | Accuracy     |Precision    | Recall | F1 Score |
# |----------------------|-------------------|--------|----------|--------------|-------------|--------|----------|
# | No Re-Sampling       | 0.46              | 0.10   | 0.16     | 0.771        | 0.452       | 0.125  | 0.196    |
# | Up Sampling          | 0.32              | 0.57   | 0.41     | 0.649        | 0.338       | 0.594  | 0.431    |
# | Down Sampling        | 0.34              | 0.63   | 0.44     | 0.645        | 0.338       | 0.615  | 0.436    |
# | SMOTE                | 0.31              | 0.42   | 0.36     | 0.655        | 0.332       | 0.451  | 0.369    |
# | ADASYN               | 0.32              | 0.42   | 0.36     | 0.649        | 0.304       | 0.452  | 0.361    |
# | SMOTE & ENN          | 0.32              | 0.42   | 0.36     | 0.649        | 0.304       | 0.442  | 0.360    |
#
#
#
#
# Based on the above table and looking at specifically F1 score of the overall model, I would recommend using up sampling.

# %% [markdown]
# ## Model Building
#
# Recall that our task is to build a model with quantitative and behavioural factors. So far we have seen that install/income is a key quantitative element in classifying loan default. However, we now need to add behavioural factors such as Home Ownership, Employment Length and Job to see how well our model will run as compared to running all the given features available.
#
# For our model building and model selection we will be using 3 different classification models.
# - Logisitic Regression
# - Decision Tree
# - SVM with a linear kernel
# - K Nearest Neighbours
#
# We will perform a 10-fold for our cross validation to be understand how well each model does.
#
#
# For each model building we will be testing various combinations of predictors rather than a full model to come up with the best model we feel can work with this data. Each of the models will contain Install/Income as we showed that it has significant association with loan default.
#
# **Model 0:** All Features
# **Model 1:** Install/Income
# **Model 2:** Install/Income + Home Ownership
# **Model 3:** Install/Income + Employment Length
# **Model 4:** Install/Income + Job (By Sector)
# **Model 5:** Install/Income + Home Ownership + Employment Length
# **Model 6:** Install/Income + Home Ownership + Job (By Sector)
# **Model 7:** Install/Income + Job (By Sector) + Employment Length
# **Model 8:** Install/Income + Home Ownership + Employment Length + Job (By Sector)

# %% [markdown]
# ### Cross Validation Function
#
# Here we define how we conduct our cross validation, using resampling technique. For our measuring technique, we will once again use F1 score.

# %%
df_modelling = loan2.copy()
# Re-sampling Functions
def down_sampling(X_train, Y_train):
    train_concat = pd.concat([X_train, Y_train], axis = 1)
    majority     = train_concat[train_concat['loan_default']==0]
    minority     = train_concat[train_concat['loan_default']==1]
    from sklearn.utils import resample
    majority_downsampled = resample( majority,
                                     replace=True,    # sample without replacement
                                     n_samples = len(minority),     # to match minority class
                                     )

    downsampled = pd.concat([majority_downsampled, minority])
    downsampled = downsampled.sample(frac=1)

    # Dividing training with target variable and predictors
    X = downsampled.drop('loan_default', axis=1)
    Y = downsampled[['loan_default']]
    return X, Y
def up_sampling(X_train, Y_train):
    train_concat = pd.concat([X_train, Y_train], axis = 1)
    majority     = train_concat[train_concat['loan_default']==0]
    minority     = train_concat[train_concat['loan_default']==1]
    from sklearn.utils import resample
    minority_upsampled = resample( minority,
                                   replace=True,    # sample without replacement
                                   n_samples = len(majority),     # to match minority class
                                   )

    upsampled = pd.concat([majority, minority_upsampled])
    upsampled = upsampled.sample(frac=1)

    # Dividing training with target variable and predictors
    X = upsampled.drop('loan_default', axis=1)
    Y = upsampled[['loan_default']]
    return X, Y

def cross_validate(X, Y, folds):
    # Classifer Models
    from sklearn.linear_model import LogisticRegression
    from sklearn.svm import SVC
    from sklearn.neighbors import KNeighborsClassifier
    from sklearn.tree import DecisionTreeClassifier
    log = LogisticRegression(solver='lbfgs', tol=10**-4,fit_intercept=True,max_iter= 1000)
    tree= DecisionTreeClassifier(criterion='entropy')
    svm = SVC(C = 1)
    knn = KNeighborsClassifier(metric= 'euclidean')
    models = [log, tree, svm, knn]
    # Tracking f1 scores for number of folds
    log_f1_scores = []; tree_f1_scores = []; svm_f1_scores = []; knn_f1_scores = []
    for i in range(folds):
        # Perform train test split
        from sklearn.model_selection import train_test_split
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y)
        # Conduct resampling of our training data
        X_train_resample, Y_train_resample = up_sampling(X_train, Y_train)
        for model in models:
            model.fit(X_train_resample, Y_train_resample.values.ravel())
            y_pred = model.predict(X_test)
            from sklearn.metrics import f1_score
            f1 = f1_score(Y_test, y_pred)
            if model == log:
                log_f1_scores.append(f1)
            elif model == tree:
                tree_f1_scores.append(f1)
            elif model == svm:
                svm_f1_scores.append(f1)
            else:
                knn_f1_scores.append(f1)
    log_f1_mean  = round((sum(log_f1_scores)/ len(log_f1_scores))*100, 4)
    tree_f1_mean = round((sum(tree_f1_scores)/ len(tree_f1_scores))*100, 4)
    svm_f1_mean  = round((sum(svm_f1_scores)/ len(svm_f1_scores))*100, 4)
    knn_f1_mean  = round((sum(svm_f1_scores)/ len(svm_f1_scores))*100, 4)
    print("F1 Mean % of Logistic Regression: ", log_f1_mean)
    print('-----------------------------------------------------')
    print("F1 Mean % of Decision Tree      : ", tree_f1_mean)
    print('-----------------------------------------------------')
    print("F1 Mean % of SVM                : ", svm_f1_mean)
    print('-----------------------------------------------------')
    print("F1 Mean % of K Nearest Neighbor : ", knn_f1_mean)
    print('-----------------------------------------------------')

    # Cross Validation
# def CV(X,folds):
#     from sklearn.model_selection import cross_val_score
#     models = [log, tree, svm, knn]
#     model_names = ['Logistic Regression',
#                    'Decision Tree',
#                    'SVM Linear Kernel',
#                    'K Nearest Neighbor']
#     print("\nCross Validation with {} Folds".format(folds))
#     for model, name in zip(models, model_names):
#         cv_score = cross_val_score(model, X, df_modelling['loan_default'], scoring='f1', cv = folds)
#         mean_f1  = round((sum(cv_score)/ len(cv_score))*100, 4)
#
#         print("F1 Mean % of ",name, " : ", mean_f1)
#         print('-----------------------------------------------------')

# %%
print(df_modelling.shape)
df_modelling.head()
# Out:
# (5000, 34)
#    chargeoff_within_12_mths  delinq_2yrs  emp_length  grade  inq_last_12m  \
# 0                         0            0           4      6             1
# 1                         0            0           3      4             0
# 2                         0            0           1      4             6
# 3                         0            0           3      4             7
# 4                         0            0           4      4             0
#
#    num_actv_bc_tl  pub_rec_bankruptcies  term  mort_acc  num_tl_90g_dpd_24m  \
# 0               1                     0    36         0                   0
# 1               3                     0    60         1                   0
# 2               4                     0    60         3                   0
# 3               2                     0    36         4                   0
# 4               4                     0    36         0                   0
#
#    ...  jobSector_finance_bank  jobSector_hospitalitty_tourism  jobSector_law  \
# 0  ...                       0                               0              0
# 1  ...                       0                               0              0
# 2  ...                       0                               0              0
# 3  ...                       0                               0              0
# 4  ...                       0                               0              0
#
#    jobSector_maintenance  jobSector_manufacture  jobSector_other  \
# 0                      0                      0                0
# 1                      0                      0                1
# 2                      0                      0                1
# 3                      0                      0                1
# 4                      0                      0                0
#
#    jobSector_public_safety  jobSector_retail  jobSector_sci_tech  \
# 0                        0                 0                   0
# 1                        0                 0                   0
# 2                        0                 0                   0
# 3                        0                 0                   0
# 4                        0                 0                   0
#
#    jobSector_transport
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    1
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Models Using Cross Validation to test which features give us better results

# %% [markdown]
# #### Model 0: X = all features

# %%
X = df_modelling.drop(columns= 'loan_default', axis = 1)
Y = df_modelling[['loan_default']]
print("Model 1: Full Model:")
cross_validate(X, Y, folds = 10)
# Out:
# Model 1: Full Model:
# F1 Mean % of Logistic Regression:  43.8891
# -----------------------------------------------------
# F1 Mean % of Decision Tree      :  30.5564
# -----------------------------------------------------
# F1 Mean % of SVM                :  43.2507
# -----------------------------------------------------
# F1 Mean % of K Nearest Neighbor :  43.2507
# -----------------------------------------------------

# %% [markdown]
# #### Model 1: X = Install/Income

# %%
from sklearn.preprocessing import StandardScaler
X = df_modelling[['install_income_norm']]
Y = df_modelling[['loan_default']]
print("Model 1: Install/Income:")
cross_validate(X, Y, folds = 10)
# Out:
# Model 1: Install/Income:
# F1 Mean % of Logistic Regression:  38.5548
# -----------------------------------------------------
# F1 Mean % of Decision Tree      :  25.3401
# -----------------------------------------------------
# F1 Mean % of SVM                :  38.4366
# -----------------------------------------------------
# F1 Mean % of K Nearest Neighbor :  38.4366
# -----------------------------------------------------

# %% [markdown]
# #### Model 2: X = Install/Income + Home Ownership

# %%
X_cols = [col for col in df_modelling.columns if col.startswith('home') or col.startswith('install_income')]
X = df_modelling[X_cols]
Y = df_modelling[['loan_default']]
print("Model 2: Install/Income + Homeownship:")
cross_validate(X, Y, folds = 10)
# Out:
# Model 2: Install/Income + Homeownship:
# F1 Mean % of Logistic Regression:  39.3122
# -----------------------------------------------------
# F1 Mean % of Decision Tree      :  26.6475
# -----------------------------------------------------
# F1 Mean % of SVM                :  39.836
# -----------------------------------------------------
# F1 Mean % of K Nearest Neighbor :  39.836
# -----------------------------------------------------

# %% [markdown]
# #### Model 3: Install/Income + Employment Length

# %%
X = df_modelling[['install_income_norm', 'emp_length']]
Y = df_modelling[['loan_default']]
print("Model 2: Install/Income + Employment Length:")
cross_validate(X, Y, folds = 10)
# Out:
# Model 2: Install/Income + Employment Length:
# F1 Mean % of Logistic Regression:  38.8807
# -----------------------------------------------------
# F1 Mean % of Decision Tree      :  26.9418
# -----------------------------------------------------
# F1 Mean % of SVM                :  39.0555
# -----------------------------------------------------
# F1 Mean % of K Nearest Neighbor :  39.0555
# -----------------------------------------------------

# %% [markdown]
# #### Model 4: Install/Income + Job (By Sector)

# %%
X_cols = [col for col in df_modelling.columns if col.startswith('job') or col.startswith('install_income')]
X = df_modelling[X_cols]
Y = df_modelling[['loan_default']]
print("Model 2: Install/Income + Job (By Sector):")
cross_validate(X, Y, folds = 10)
# Out:
# Model 2: Install/Income + Job (By Sector):
# F1 Mean % of Logistic Regression:  39.2225
# -----------------------------------------------------
# F1 Mean % of Decision Tree      :  27.4289
# -----------------------------------------------------
# F1 Mean % of SVM                :  37.9338
# -----------------------------------------------------
# F1 Mean % of K Nearest Neighbor :  37.9338
# -----------------------------------------------------

# %% [markdown]
# #### Model 5: Install/Income + Home Ownership + Employment Length

# %%
X_cols = [col for col in df_modelling.columns if col.startswith('install_income') or col.startswith('home') or col.startswith('emp')]
X = df_modelling[X_cols]
Y = df_modelling[['loan_default']]
print("Model 2: Install/Income + Home Ownership + Employment Length")
cross_validate(X, Y, folds = 10)
# Out:
# Model 2: Install/Income + Home Ownership + Employment Length
# F1 Mean % of Logistic Regression:  39.2726
# -----------------------------------------------------
# F1 Mean % of Decision Tree      :  25.9225
# -----------------------------------------------------
# F1 Mean % of SVM                :  39.0802
# -----------------------------------------------------
# F1 Mean % of K Nearest Neighbor :  39.0802
# -----------------------------------------------------

# %% [markdown]
# #### Model 6: Install/Income + Home Ownership + Job (By Sector)

# %%
X_cols = [col for col in df_modelling.columns if col.startswith('install_income') or col.startswith('home') or col.startswith('jobSector')]
X = df_modelling[X_cols]
Y = df_modelling[['loan_default']]
print("Model 2: Install/Income + Home Ownership + Job (By Sector)")
cross_validate(X, Y, folds = 10)
# Out:
# Model 2: Install/Income + Home Ownership + Job (By Sector)
# F1 Mean % of Logistic Regression:  40.7024
# -----------------------------------------------------
# F1 Mean % of Decision Tree      :  25.8986
# -----------------------------------------------------
# F1 Mean % of SVM                :  39.3225
# -----------------------------------------------------
# F1 Mean % of K Nearest Neighbor :  39.3225
# -----------------------------------------------------

# %% [markdown]
# #### Model 7: Install/Income + Employment Length + Job (By Sector)

# %%
X_cols = [col for col in df_modelling.columns if col.startswith('install_income') or col.startswith('emp') or col.startswith('jobSector')]
X = df_modelling[X_cols]
Y = df_modelling[['loan_default']]
print("Model 2: Install/Income + Employment Length + Job (By Sector)")
cross_validate(X, Y, folds = 10)
# Out:
# Model 2: Install/Income + Employment Length + Job (By Sector)
# F1 Mean % of Logistic Regression:  38.3865
# -----------------------------------------------------
# F1 Mean % of Decision Tree      :  27.8944
# -----------------------------------------------------
# F1 Mean % of SVM                :  38.1081
# -----------------------------------------------------
# F1 Mean % of K Nearest Neighbor :  38.1081
# -----------------------------------------------------

# %% [markdown]
# #### Model 8: Install/Income + Home Ownership + Employment Length + Job (By Sector)

# %%
X_cols = [col for col in df_modelling.columns if col.startswith('install_income') or col.startswith('home') or col.startswith('emp') or col.startswith('jobSector')]
X = df_modelling[X_cols]
Y = df_modelling[['loan_default']]
print("Model 2: Install/Income + Home Ownership + Employment Length + Job (By Sector)")
cross_validate(X, Y, folds = 10)
# Out:
# Model 2: Install/Income + Home Ownership + Employment Length + Job (By Sector)
# F1 Mean % of Logistic Regression:  39.6653
# -----------------------------------------------------
# F1 Mean % of Decision Tree      :  26.2766
# -----------------------------------------------------
# F1 Mean % of SVM                :  38.9241
# -----------------------------------------------------
# F1 Mean % of K Nearest Neighbor :  38.9241
# -----------------------------------------------------

# %% [markdown]
# Based on all the various models we have tested, we can see that the Decision Tree gives us the best score in terms of F1 Score. Furthermore, we can also see that by adding the Job behavorial factor with install/income, we come to the closest "best" model as compared to our full model. We can now try and dive deeper into the decision tree and seeing if we can have a visualization of how our model will look like.

# %% [markdown]
# ### Decision Tree

# %% [markdown]
# #### Train Test

# %%
X_cols = [col for col in df_modelling.columns if col.startswith('install_income') or col.startswith('jobSector')]
X = df_modelling[X_cols]

Y = df_modelling[['loan_default']]

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state= 1)

# %%
# Decision Tree
tree = DecisionTreeClassifier(criterion= "entropy", random_state= 2).fit(X_train, Y_train)

# %%
# Plot of Tree
plt.figure(figsize=(30,5))
from sklearn.tree import plot_tree
plot_tree(tree,
          filled = True,
          rounded= True,
          class_names=["No Default", "Default"],

          feature_names= X.columns)
# Out:
# [Text(0.6274725377747759, 0.9941176470588236, 'install_income_norm <= 0.561\nentropy = 1.0\nsamples = 4032\nvalue = [2014, 2018]\nclass = Default'),
#  Text(0.36251924391408485, 0.9823529411764705, 'install_income_norm <= 0.238\nentropy = 0.991\nsamples = 2750\nvalue = [1526, 1224]\nclass = No Default'),
#  Text(0.09323202303992156, 0.9705882352941176, 'jobSector_other <= 0.5\nentropy = 0.912\nsamples = 566\nvalue = [381, 185]\nclass = No Default'),
#  Text(0.06832317166579858, 0.9588235294117647, 'install_income_norm <= 0.23\nentropy = 0.826\nsamples = 316\nvalue = [234, 82]\nclass = No Default'),
#  Text(0.05625172339838843, 0.9470588235294117, 'install_income_norm <= 0.225\nentropy = 0.788\nsamples = 284\nvalue = [217, 67]\nclass = No Default'),
#  Text(0.054290879009773585, 0.9352941176470588, 'install_income_norm <= 0.224\nentropy = 0.811\nsamples = 268\nvalue = [201, 67]\nclass = No Default'),
#  Text(0.05233003462115873, 0.9235294117647059, 'jobSector_education <= 0.5\nentropy = 0.798\nsamples = 265\nvalue = [201, 64]\nclass = No Default'),
#  Text(0.03603051564079782, 0.9117647058823529, 'install_income_norm <= 0.067\nentropy = 0.755\nsamples = 244\nvalue = [191, 53]\nclass = No Default'),
#  Text(0.03406967125218297, 0.9, 'entropy = 0.0\nsamples = 19\nvalue = [19, 0]\nclass = No Default'),
#  Text(0.03799136002941267, 0.9, 'install_income_norm <= 0.135\nentropy = 0.788\nsamples = 225\nvalue = [172, 53]\nclass = No Default'),
#  Text(0.016667177303226203, 0.888235294117647, 'install_income_norm <= 0.069\nentropy = 0.94\nsamples = 84\nvalue = [54, 30]\nclass = No Default'),
#  Text(0.014706332914611354, 0.8764705882352941, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.018628021691841048, 0.8764705882352941, 'install_income_norm <= 0.089\nentropy = 0.918\nsamples = 81\nvalue = [54, 27]\nclass = No Default'),
#  Text(0.016667177303226203, 0.8647058823529412, 'entropy = 0.0\nsamples = 17\nvalue = [17, 0]\nclass = No Default'),
#  Text(0.020588866080455896, 0.8647058823529412, 'jobSector_business_execs <= 0.5\nentropy = 0.982\nsamples = 64\nvalue = [37, 27]\nclass = No Default'),
#  Text(0.018628021691841048, 0.8529411764705882, 'install_income_norm <= 0.111\nentropy = 0.993\nsamples = 60\nvalue = [33, 27]\nclass = No Default'),
#  Text(0.007843377554459388, 0.8411764705882353, 'install_income_norm <= 0.095\nentropy = 0.971\nsamples = 25\nvalue = [10, 15]\nclass = Default'),
#  Text(0.003921688777229694, 0.8294117647058824, 'install_income_norm <= 0.09\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]\nclass = No Default'),
#  Text(0.001960844388614847, 0.8176470588235294, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.005882533165844542, 0.8176470588235294, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No Default'),
#  Text(0.011765066331689084, 0.8294117647058824, 'install_income_norm <= 0.096\nentropy = 0.852\nsamples = 18\nvalue = [5, 13]\nclass = Default'),
#  Text(0.009804221943074237, 0.8176470588235294, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Default'),
#  Text(0.01372591072030393, 0.8176470588235294, 'install_income_norm <= 0.103\nentropy = 0.994\nsamples = 11\nvalue = [5, 6]\nclass = Default'),
#  Text(0.011765066331689084, 0.8058823529411765, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.015686755108918777, 0.8058823529411765, 'jobSector_sci_tech <= 0.5\nentropy = 0.918\nsamples = 9\nvalue = [3, 6]\nclass = Default'),
#  Text(0.01372591072030393, 0.7941176470588235, 'install_income_norm <= 0.106\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]\nclass = Default'),
#  Text(0.011765066331689084, 0.7823529411764706, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Default'),
#  Text(0.015686755108918777, 0.7823529411764706, 'install_income_norm <= 0.108\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Default'),
#  Text(0.01372591072030393, 0.7705882352941177, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.017647599497533625, 0.7705882352941177, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.017647599497533625, 0.7941176470588235, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.02941266582922271, 0.8411764705882353, 'install_income_norm <= 0.124\nentropy = 0.928\nsamples = 35\nvalue = [23, 12]\nclass = No Default'),
#  Text(0.02745182144060786, 0.8294117647058824, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = No Default'),
#  Text(0.031373510217837554, 0.8294117647058824, 'jobSector_law <= 0.5\nentropy = 0.999\nsamples = 23\nvalue = [11, 12]\nclass = Default'),
#  Text(0.02941266582922271, 0.8176470588235294, 'install_income_norm <= 0.135\nentropy = 0.982\nsamples = 19\nvalue = [11, 8]\nclass = No Default'),
#  Text(0.02745182144060786, 0.8058823529411765, 'install_income_norm <= 0.13\nentropy = 0.937\nsamples = 17\nvalue = [11, 6]\nclass = No Default'),
#  Text(0.025490977051993016, 0.7941176470588235, 'install_income_norm <= 0.13\nentropy = 1.0\nsamples = 12\nvalue = [6, 6]\nclass = No Default'),
#  Text(0.023530132663378167, 0.7823529411764706, 'install_income_norm <= 0.128\nentropy = 0.918\nsamples = 9\nvalue = [6, 3]\nclass = No Default'),
#  Text(0.02156928827476332, 0.7705882352941177, 'install_income_norm <= 0.126\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = Default'),
#  Text(0.019608443886148474, 0.7588235294117647, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.023530132663378167, 0.7588235294117647, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.025490977051993016, 0.7705882352941177, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No Default'),
#  Text(0.02745182144060786, 0.7823529411764706, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.02941266582922271, 0.7941176470588235, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No Default'),
#  Text(0.031373510217837554, 0.8058823529411765, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.033334354606452406, 0.8176470588235294, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Default'),
#  Text(0.022549710469070745, 0.8529411764705882, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No Default'),
#  Text(0.05931554275559913, 0.888235294117647, 'jobSector_public_safety <= 0.5\nentropy = 0.642\nsamples = 141\nvalue = [118, 23]\nclass = No Default'),
#  Text(0.05196237629829345, 0.8764705882352941, 'jobSector_business_execs <= 0.5\nentropy = 0.541\nsamples = 129\nvalue = [113, 16]\nclass = No Default'),
#  Text(0.047060265326756334, 0.8647058823529412, 'install_income_norm <= 0.194\nentropy = 0.374\nsamples = 111\nvalue = [103, 8]\nclass = No Default'),
#  Text(0.04313857654952664, 0.8529411764705882, 'install_income_norm <= 0.177\nentropy = 0.183\nsamples = 72\nvalue = [70, 2]\nclass = No Default'),
#  Text(0.04117773216091179, 0.8411764705882353, 'install_income_norm <= 0.176\nentropy = 0.267\nsamples = 44\nvalue = [42, 2]\nclass = No Default'),
#  Text(0.03921688777229695, 0.8294117647058824, 'install_income_norm <= 0.155\nentropy = 0.159\nsamples = 43\nvalue = [42, 1]\nclass = No Default'),
#  Text(0.037256043383682096, 0.8176470588235294, 'install_income_norm <= 0.154\nentropy = 0.337\nsamples = 16\nvalue = [15, 1]\nclass = No Default'),
#  Text(0.03529519899506725, 0.8058823529411765, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = No Default'),
#  Text(0.03921688777229695, 0.8058823529411765, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Default'),
#  Text(0.04117773216091179, 0.8176470588235294, 'entropy = 0.0\nsamples = 27\nvalue = [27, 0]\nclass = No Default'),
#  Text(0.04313857654952664, 0.8294117647058824, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Default'),
#  Text(0.04509942093814149, 0.8411764705882353, 'entropy = 0.0\nsamples = 28\nvalue = [28, 0]\nclass = No Default'),
#  Text(0.05098195410398603, 0.8529411764705882, 'install_income_norm <= 0.196\nentropy = 0.619\nsamples = 39\nvalue = [33, 6]\nclass = No Default'),
#  Text(0.04902110971537118, 0.8411764705882353, 'install_income_norm <= 0.195\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]\nclass = Default'),
#  Text(0.047060265326756334, 0.8294117647058824, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Default'),
#  Text(0.05098195410398603, 0.8294117647058824, 'install_income_norm <= 0.195\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Default'),
#  Text(0.04902110971537118, 0.8176470588235294, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.052942798492600876, 0.8176470588235294, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.052942798492600876, 0.8411764705882353, 'entropy = 0.0\nsamples = 32\nvalue = [32, 0]\nclass = No Default'),
#  Text(0.05686448726983057, 0.8647058823529412, 'install_income_norm <= 0.165\nentropy = 0.991\nsamples = 18\nvalue = [10, 8]\nclass = No Default'),
#  Text(0.05490364288121572, 0.8529411764705882, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Default'),
#  Text(0.05882533165844542, 0.8529411764705882, 'install_income_norm <= 0.194\nentropy = 0.779\nsamples = 13\nvalue = [10, 3]\nclass = No Default'),
#  Text(0.05686448726983057, 0.8411764705882353, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = No Default'),
#  Text(0.06078617604706026, 0.8411764705882353, 'install_income_norm <= 0.207\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]\nclass = No Default'),
#  Text(0.05882533165844542, 0.8294117647058824, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Default'),
#  Text(0.06274702043567511, 0.8294117647058824, 'install_income_norm <= 0.221\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]\nclass = No Default'),
#  Text(0.06078617604706026, 0.8176470588235294, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No Default'),
#  Text(0.06470786482428996, 0.8176470588235294, 'install_income_norm <= 0.224\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Default'),
#  Text(0.06274702043567511, 0.8058823529411765, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.06666870921290481, 0.8058823529411765, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.06666870921290481, 0.8764705882352941, 'install_income_norm <= 0.192\nentropy = 0.98\nsamples = 12\nvalue = [5, 7]\nclass = Default'),
#  Text(0.06470786482428996, 0.8647058823529412, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.06862955360151965, 0.8647058823529412, 'install_income_norm <= 0.21\nentropy = 0.881\nsamples = 10\nvalue = [3, 7]\nclass = Default'),
#  Text(0.06666870921290481, 0.8529411764705882, 'install_income_norm <= 0.204\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]\nclass = Default'),
#  Text(0.06470786482428996, 0.8411764705882353, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Default'),
#  Text(0.06862955360151965, 0.8411764705882353, 'install_income_norm <= 0.207\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = Default'),
#  Text(0.06666870921290481, 0.8294117647058824, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.0705903979901345, 0.8294117647058824, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.0705903979901345, 0.8529411764705882, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.06862955360151965, 0.9117647058823529, 'install_income_norm <= 0.016\nentropy = 0.998\nsamples = 21\nvalue = [10, 11]\nclass = Default'),
#  Text(0.06666870921290481, 0.9, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Default'),
#  Text(0.0705903979901345, 0.9, 'install_income_norm <= 0.182\nentropy = 0.918\nsamples = 15\nvalue = [10, 5]\nclass = No Default'),
#  Text(0.06862955360151965, 0.888235294117647, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = No Default'),
#  Text(0.07255124237874935, 0.888235294117647, 'install_income_norm <= 0.188\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]\nclass = Default'),
#  Text(0.0705903979901345, 0.8764705882352941, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Default'),
#  Text(0.07451208676736419, 0.8764705882352941, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.05625172339838843, 0.9235294117647059, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.058212567787003275, 0.9352941176470588, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]\nclass = No Default'),
#  Text(0.08039461993320873, 0.9470588235294117, 'install_income_norm <= 0.232\nentropy = 0.997\nsamples = 32\nvalue = [17, 15]\nclass = No Default'),
#  Text(0.07647293115597904, 0.9352941176470588, 'install_income_norm <= 0.231\nentropy = 0.439\nsamples = 11\nvalue = [1, 10]\nclass = Default'),
#  Text(0.07451208676736419, 0.9235294117647059, 'install_income_norm <= 0.231\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = Default'),
#  Text(0.07255124237874935, 0.9117647058823529, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.07647293115597904, 0.9117647058823529, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.0784337755445939, 0.9235294117647059, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Default'),
#  Text(0.08431630871043844, 0.9352941176470588, 'jobSector_business_execs <= 0.5\nentropy = 0.792\nsamples = 21\nvalue = [16, 5]\nclass = No Default'),
#  Text(0.08235546432182358, 0.9235294117647059, 'jobSector_transport <= 0.5\nentropy = 0.503\nsamples = 18\nvalue = [16, 2]\nclass = No Default'),
#  Text(0.08039461993320873, 0.9117647058823529, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = No Default'),
#  Text(0.08431630871043844, 0.9117647058823529, 'install_income_norm <= 0.235\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = No Default'),
#  Text(0.08235546432182358, 0.9, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.08627715309905327, 0.9, 'install_income_norm <= 0.237\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Default'),
#  Text(0.08431630871043844, 0.888235294117647, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.08823799748766813, 0.888235294117647, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.08627715309905327, 0.9235294117647059, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.11814087441404454, 0.9588235294117647, 'install_income_norm <= 0.233\nentropy = 0.978\nsamples = 250\nvalue = [147, 103]\nclass = No Default'),
#  Text(0.1161800300254297, 0.9470588235294117, 'install_income_norm <= 0.028\nentropy = 0.984\nsamples = 242\nvalue = [139, 103]\nclass = No Default'),
#  Text(0.11421918563681485, 0.9352941176470588, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = No Default'),
#  Text(0.11814087441404454, 0.9352941176470588, 'install_income_norm <= 0.108\nentropy = 0.988\nsamples = 236\nvalue = [133, 103]\nclass = No Default'),
#  Text(0.09706179723643495, 0.9235294117647059, 'install_income_norm <= 0.03\nentropy = 0.974\nsamples = 69\nvalue = [28, 41]\nclass = Default'),
#  Text(0.0951009528478201, 0.9117647058823529, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Default'),
#  Text(0.09902264162504978, 0.9117647058823529, 'install_income_norm <= 0.054\nentropy = 0.986\nsamples = 65\nvalue = [28, 37]\nclass = Default'),
#  Text(0.09412053065351267, 0.9, 'install_income_norm <= 0.038\nentropy = 0.684\nsamples = 11\nvalue = [9, 2]\nclass = No Default'),
#  Text(0.09215968626489782, 0.888235294117647, 'install_income_norm <= 0.033\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = No Default'),
#  Text(0.09019884187628298, 0.8764705882352941, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No Default'),
#  Text(0.09412053065351267, 0.8764705882352941, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.09608137504212752, 0.888235294117647, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = No Default'),
#  Text(0.1039247525965869, 0.9, 'install_income_norm <= 0.065\nentropy = 0.936\nsamples = 54\nvalue = [19, 35]\nclass = Default'),
#  Text(0.10000306381935721, 0.888235294117647, 'install_income_norm <= 0.06\nentropy = 0.391\nsamples = 13\nvalue = [1, 12]\nclass = Default'),
#  Text(0.09804221943074236, 0.8764705882352941, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Default'),
#  Text(0.10196390820797206, 0.8764705882352941, 'install_income_norm <= 0.065\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]\nclass = Default'),
#  Text(0.10000306381935721, 0.8647058823529412, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.1039247525965869, 0.8647058823529412, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Default'),
#  Text(0.1078464413738166, 0.888235294117647, 'install_income_norm <= 0.077\nentropy = 0.989\nsamples = 41\nvalue = [18, 23]\nclass = Default'),
#  Text(0.10588559698520175, 0.8764705882352941, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = No Default'),
#  Text(0.10980728576243144, 0.8764705882352941, 'install_income_norm <= 0.078\nentropy = 0.908\nsamples = 34\nvalue = [11, 23]\nclass = Default'),
#  Text(0.1078464413738166, 0.8647058823529412, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Default'),
#  Text(0.1117681301510463, 0.8647058823529412, 'install_income_norm <= 0.103\nentropy = 0.99\nsamples = 25\nvalue = [11, 14]\nclass = Default'),
#  Text(0.1078464413738166, 0.8529411764705882, 'install_income_norm <= 0.09\nentropy = 0.89\nsamples = 13\nvalue = [9, 4]\nclass = No Default'),
#  Text(0.10588559698520175, 0.8411764705882353, 'install_income_norm <= 0.086\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]\nclass = Default'),
#  Text(0.1039247525965869, 0.8294117647058824, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.1078464413738166, 0.8294117647058824, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Default'),
#  Text(0.10980728576243144, 0.8411764705882353, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = No Default'),
#  Text(0.11568981892827598, 0.8529411764705882, 'install_income_norm <= 0.104\nentropy = 0.65\nsamples = 12\nvalue = [2, 10]\nclass = Default'),
#  Text(0.11372897453966115, 0.8411764705882353, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]\nclass = Default'),
#  Text(0.11765066331689084, 0.8411764705882353, 'install_income_norm <= 0.107\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = No Default'),
#  Text(0.11568981892827598, 0.8294117647058824, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.11961150770550569, 0.8294117647058824, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.13921995159165415, 0.9235294117647059, 'install_income_norm <= 0.187\nentropy = 0.952\nsamples = 167\nvalue = [105, 62]\nclass = No Default'),
#  Text(0.13137657403719477, 0.9117647058823529, 'install_income_norm <= 0.168\nentropy = 0.678\nsamples = 67\nvalue = [55, 12]\nclass = No Default'),
#  Text(0.12941572964857992, 0.9, 'install_income_norm <= 0.166\nentropy = 0.779\nsamples = 52\nvalue = [40, 12]\nclass = No Default'),
#  Text(0.12745488525996507, 0.888235294117647, 'install_income_norm <= 0.13\nentropy = 0.722\nsamples = 50\nvalue = [40, 10]\nclass = No Default'),
#  Text(0.12549404087135022, 0.8764705882352941, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = No Default'),
#  Text(0.12941572964857992, 0.8764705882352941, 'install_income_norm <= 0.13\nentropy = 0.801\nsamples = 41\nvalue = [31, 10]\nclass = No Default'),
#  Text(0.12745488525996507, 0.8647058823529412, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Default'),
#  Text(0.13137657403719477, 0.8647058823529412, 'install_income_norm <= 0.159\nentropy = 0.639\nsamples = 37\nvalue = [31, 6]\nclass = No Default'),
#  Text(0.12745488525996507, 0.8529411764705882, 'install_income_norm <= 0.136\nentropy = 0.381\nsamples = 27\nvalue = [25, 2]\nclass = No Default'),
#  Text(0.12549404087135022, 0.8411764705882353, 'install_income_norm <= 0.133\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = No Default'),
#  Text(0.12353319648273538, 0.8294117647058824, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.12745488525996507, 0.8294117647058824, 'install_income_norm <= 0.134\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Default'),
#  Text(0.12549404087135022, 0.8176470588235294, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Default'),
#  Text(0.12941572964857992, 0.8176470588235294, 'install_income_norm <= 0.134\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = No Default'),
#  Text(0.12745488525996507, 0.8058823529411765, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.13137657403719477, 0.8058823529411765, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Default'),
#  Text(0.12941572964857992, 0.8411764705882353, 'entropy = 0.0\nsamples = 22\nvalue = [22, 0]\nclass = No Default'),
#  Text(0.13529826281442447, 0.8529411764705882, 'install_income_norm <= 0.161\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]\nclass = No Default'),
#  Text(0.13333741842580962, 0.8411764705882353, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Default'),
#  Text(0.1372591072030393, 0.8411764705882353, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = No Default'),
#  Text(0.13137657403719477, 0.888235294117647, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.13333741842580962, 0.9, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = No Default'),
#  Text(0.14706332914611356, 0.9117647058823529, 'install_income_norm <= 0.191\nentropy = 1.0\nsamples = 100\nvalue = [50, 50]\nclass = No Default'),
#  Text(0.14314164036888385, 0.9, 'install_income_norm <= 0.189\nentropy = 0.722\nsamples = 15\nvalue = [3, 12]\nclass = Default'),
#  Text(0.141180795980269, 0.888235294117647, 'install_income_norm <= 0.188\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]\nclass = No Default'),
#  Text(0.13921995159165415, 0.8764705882352941, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.14314164036888385, 0.8764705882352941, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No Default'),
#  Text(0.1451024847574987, 0.888235294117647, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Default'),
#  Text(0.15098501792334323, 0.9, 'install_income_norm <= 0.233\nentropy = 0.992\nsamples = 85\nvalue = [47, 38]\nclass = No Default'),
#  Text(0.14902417353472838, 0.888235294117647, 'install_income_norm <= 0.229\nentropy = 0.984\nsamples = 82\nvalue = [47, 35]\nclass = No Default'),
#  Text(0.14706332914611356, 0.8764705882352941, 'install_income_norm <= 0.228\nentropy = 0.998\nsamples = 74\nvalue = [39, 35]\nclass = No Default'),
#  Text(0.1451024847574987, 0.8647058823529412, 'install_income_norm <= 0.224\nentropy = 0.988\nsamples = 69\nvalue = [39, 30]\nclass = No Default'),
#  Text(0.14314164036888385, 0.8529411764705882, 'install_income_norm <= 0.198\nentropy = 0.998\nsamples = 63\nvalue = [33, 30]\nclass = No Default'),
#  Text(0.141180795980269, 0.8411764705882353, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No Default'),
#  Text(0.1451024847574987, 0.8411764705882353, 'install_income_norm <= 0.2\nentropy = 1.0\nsamples = 59\nvalue = [29, 30]\nclass = Default'),
#  Text(0.14314164036888385, 0.8294117647058824, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Default'),
#  Text(0.14706332914611356, 0.8294117647058824, 'install_income_norm <= 0.223\nentropy = 0.996\nsamples = 54\nvalue = [29, 25]\nclass = No Default'),
#  Text(0.1451024847574987, 0.8176470588235294, 'install_income_norm <= 0.202\nentropy = 0.99\nsamples = 52\nvalue = [29, 23]\nclass = No Default'),
#  Text(0.14314164036888385, 0.8058823529411765, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.14706332914611356, 0.8058823529411765, 'install_income_norm <= 0.202\nentropy = 0.995\nsamples = 50\nvalue = [27, 23]\nclass = No Default'),
#  Text(0.1451024847574987, 0.7941176470588235, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.14902417353472838, 0.7941176470588235, 'install_income_norm <= 0.205\nentropy = 0.984\nsamples = 47\nvalue = [27, 20]\nclass = No Default'),
#  Text(0.14706332914611356, 0.7823529411764706, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No Default'),
#  Text(0.15098501792334323, 0.7823529411764706, 'install_income_norm <= 0.207\nentropy = 0.998\nsamples = 42\nvalue = [22, 20]\nclass = No Default'),
#  Text(0.14902417353472838, 0.7705882352941177, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Default'),
#  Text(0.1529458623119581, 0.7705882352941177, 'install_income_norm <= 0.21\nentropy = 0.974\nsamples = 37\nvalue = [22, 15]\nclass = No Default'),
#  Text(0.15098501792334323, 0.7588235294117647, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = No Default'),
#  Text(0.15490670670057294, 0.7588235294117647, 'install_income_norm <= 0.211\nentropy = 1.0\nsamples = 30\nvalue = [15, 15]\nclass = No Default'),
#  Text(0.1529458623119581, 0.7470588235294118, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.1568675510891878, 0.7470588235294118, 'install_income_norm <= 0.214\nentropy = 0.996\nsamples = 28\nvalue = [15, 13]\nclass = No Default'),
#  Text(0.15490670670057294, 0.7352941176470589, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No Default'),
#  Text(0.15882839547780264, 0.7352941176470589, 'install_income_norm <= 0.216\nentropy = 0.995\nsamples = 24\nvalue = [11, 13]\nclass = Default'),
#  Text(0.1568675510891878, 0.7235294117647059, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.16078923986641747, 0.7235294117647059, 'install_income_norm <= 0.218\nentropy = 0.998\nsamples = 21\nvalue = [11, 10]\nclass = No Default'),
#  Text(0.15882839547780264, 0.711764705882353, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No Default'),
#  Text(0.16275008425503232, 0.711764705882353, 'install_income_norm <= 0.219\nentropy = 0.991\nsamples = 18\nvalue = [8, 10]\nclass = Default'),
#  Text(0.16078923986641747, 0.7, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.16471092864364717, 0.7, 'install_income_norm <= 0.219\nentropy = 0.997\nsamples = 15\nvalue = [8, 7]\nclass = No Default'),
#  Text(0.16275008425503232, 0.6882352941176471, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.16667177303226202, 0.6882352941176471, 'install_income_norm <= 0.219\nentropy = 0.996\nsamples = 13\nvalue = [6, 7]\nclass = Default'),
#  Text(0.16471092864364717, 0.6764705882352942, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Default'),
#  Text(0.16863261742087687, 0.6764705882352942, 'install_income_norm <= 0.221\nentropy = 0.918\nsamples = 9\nvalue = [6, 3]\nclass = No Default'),
#  Text(0.16667177303226202, 0.6647058823529411, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No Default'),
#  Text(0.17059346180949173, 0.6647058823529411, 'install_income_norm <= 0.222\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = Default'),
#  Text(0.16863261742087687, 0.6529411764705882, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.17255430619810655, 0.6529411764705882, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.14902417353472838, 0.8176470588235294, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.14706332914611356, 0.8529411764705882, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = No Default'),
#  Text(0.14902417353472838, 0.8647058823529412, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Default'),
#  Text(0.15098501792334323, 0.8764705882352941, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = No Default'),
#  Text(0.1529458623119581, 0.888235294117647, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.1201017188026594, 0.9470588235294117, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = No Default'),
#  Text(0.6318064647882482, 0.9705882352941176, 'jobSector_transport <= 0.5\nentropy = 0.998\nsamples = 2184\nvalue = [1145, 1039]\nclass = No Default'),
#  Text(0.5536034317364891, 0.9588235294117647, 'install_income_norm <= 0.558\nentropy = 0.997\nsamples = 2086\nvalue = [1112, 974]\nclass = No Default'),
#  Text(0.43960062553676676, 0.9470588235294117, 'jobSector_business_execs <= 0.5\nentropy = 0.997\nsamples = 2069\nvalue = [1097, 972]\nclass = No Default'),
#  Text(0.22336007946901137, 0.9352941176470588, 'install_income_norm <= 0.241\nentropy = 0.998\nsamples = 1990\nvalue = [1042, 948]\nclass = No Default'),
#  Text(0.16275008425503232, 0.9235294117647059, 'jobSector_education <= 0.5\nentropy = 0.722\nsamples = 20\nvalue = [4, 16]\nclass = Default'),
#  Text(0.16078923986641747, 0.9117647058823529, 'jobSector_finance_bank <= 0.5\nentropy = 0.629\nsamples = 19\nvalue = [3, 16]\nclass = Default'),
#  Text(0.15882839547780264, 0.9, 'jobSector_public_safety <= 0.5\nentropy = 0.75\nsamples = 14\nvalue = [3, 11]\nclass = Default'),
#  Text(0.1568675510891878, 0.888235294117647, 'install_income_norm <= 0.24\nentropy = 0.845\nsamples = 11\nvalue = [3, 8]\nclass = Default'),
#  Text(0.15490670670057294, 0.8764705882352941, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.15882839547780264, 0.8764705882352941, 'jobSector_other <= 0.5\nentropy = 0.503\nsamples = 9\nvalue = [1, 8]\nclass = Default'),
#  Text(0.1568675510891878, 0.8647058823529412, 'jobSector_sci_tech <= 0.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = Default'),
#  Text(0.15490670670057294, 0.8529411764705882, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.15882839547780264, 0.8529411764705882, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.16078923986641747, 0.8647058823529412, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Default'),
#  Text(0.16078923986641747, 0.888235294117647, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.16275008425503232, 0.9, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Default'),
#  Text(0.16471092864364717, 0.9117647058823529, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.28397007468299046, 0.9235294117647059, 'install_income_norm <= 0.244\nentropy = 0.998\nsamples = 1970\nvalue = [1038, 932]\nclass = No Default'),
#  Text(0.2820092302943756, 0.9117647058823529, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = No Default'),
#  Text(0.2859309190716053, 0.9117647058823529, 'install_income_norm <= 0.247\nentropy = 0.998\nsamples = 1960\nvalue = [1028, 932]\nclass = No Default'),
#  Text(0.16667177303226202, 0.9, 'install_income_norm <= 0.245\nentropy = 0.469\nsamples = 20\nvalue = [2, 18]\nclass = Default'),
#  Text(0.16471092864364717, 0.888235294117647, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Default'),
#  Text(0.16863261742087687, 0.888235294117647, 'install_income_norm <= 0.245\nentropy = 0.592\nsamples = 14\nvalue = [2, 12]\nclass = Default'),
#  Text(0.16667177303226202, 0.8764705882352941, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.17059346180949173, 0.8764705882352941, 'install_income_norm <= 0.246\nentropy = 0.391\nsamples = 13\nvalue = [1, 12]\nclass = Default'),
#  Text(0.16863261742087687, 0.8647058823529412, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Default'),
#  Text(0.17255430619810655, 0.8647058823529412, 'install_income_norm <= 0.246\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]\nclass = Default'),
#  Text(0.17059346180949173, 0.8529411764705882, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.1745151505867214, 0.8529411764705882, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Default'),
#  Text(0.40519006511094857, 0.9, 'install_income_norm <= 0.296\nentropy = 0.998\nsamples = 1940\nvalue = [1026, 914]\nclass = No Default'),
#  Text(0.20239590673733876, 0.888235294117647, 'install_income_norm <= 0.291\nentropy = 0.94\nsamples = 252\nvalue = [162, 90]\nclass = No Default'),
#  Text(0.18934403627562119, 0.8764705882352941, 'install_income_norm <= 0.29\nentropy = 0.964\nsamples = 224\nvalue = [137, 87]\nclass = No Default'),
#  Text(0.18039768375256596, 0.8647058823529412, 'install_income_norm <= 0.25\nentropy = 0.945\nsamples = 212\nvalue = [135, 77]\nclass = No Default'),
#  Text(0.1784368393639511, 0.8529411764705882, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]\nclass = No Default'),
#  Text(0.1823585281411808, 0.8529411764705882, 'install_income_norm <= 0.251\nentropy = 0.959\nsamples = 202\nvalue = [125, 77]\nclass = No Default'),
#  Text(0.17034835626091485, 0.8411764705882353, 'install_income_norm <= 0.25\nentropy = 0.439\nsamples = 11\nvalue = [1, 10]\nclass = Default'),
#  Text(0.1683875118723, 0.8294117647058824, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Default'),
#  Text(0.1723092006495297, 0.8294117647058824, 'install_income_norm <= 0.25\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = Default'),
#  Text(0.17034835626091485, 0.8176470588235294, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.17427004503814456, 0.8176470588235294, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Default'),
#  Text(0.19436870002144674, 0.8411764705882353, 'install_income_norm <= 0.263\nentropy = 0.935\nsamples = 191\nvalue = [124, 67]\nclass = No Default'),
#  Text(0.18309384478691137, 0.8294117647058824, 'install_income_norm <= 0.252\nentropy = 0.65\nsamples = 48\nvalue = [40, 8]\nclass = No Default'),
#  Text(0.17819173381537426, 0.8176470588235294, 'install_income_norm <= 0.252\nentropy = 0.98\nsamples = 12\nvalue = [7, 5]\nclass = No Default'),
#  Text(0.1762308894267594, 0.8058823529411765, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = No Default'),
#  Text(0.18015257820398908, 0.8058823529411765, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Default'),
#  Text(0.1879959557584485, 0.8176470588235294, 'jobSector_sci_tech <= 0.5\nentropy = 0.414\nsamples = 36\nvalue = [33, 3]\nclass = No Default'),
#  Text(0.1840742669812188, 0.8058823529411765, 'jobSector_other <= 0.5\nentropy = 0.196\nsamples = 33\nvalue = [32, 1]\nclass = No Default'),
#  Text(0.18211342259260394, 0.7941176470588235, 'entropy = 0.0\nsamples = 17\nvalue = [17, 0]\nclass = No Default'),
#  Text(0.18603511136983364, 0.7941176470588235, 'install_income_norm <= 0.257\nentropy = 0.337\nsamples = 16\nvalue = [15, 1]\nclass = No Default'),
#  Text(0.1840742669812188, 0.7823529411764706, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = No Default'),
#  Text(0.1879959557584485, 0.7823529411764706, 'install_income_norm <= 0.258\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]\nclass = No Default'),
#  Text(0.18603511136983364, 0.7705882352941177, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Default'),
#  Text(0.18995680014706334, 0.7705882352941177, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = No Default'),
#  Text(0.19191764453567817, 0.8058823529411765, 'install_income_norm <= 0.261\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Default'),
#  Text(0.18995680014706334, 0.7941176470588235, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.19387848892429302, 0.7941176470588235, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.2056435552559821, 0.8294117647058824, 'install_income_norm <= 0.264\nentropy = 0.978\nsamples = 143\nvalue = [84, 59]\nclass = No Default'),
#  Text(0.19780017770152272, 0.8176470588235294, 'jobSector_other <= 0.5\nentropy = 0.567\nsamples = 15\nvalue = [2, 13]\nclass = Default'),
#  Text(0.19583933331290787, 0.8058823529411765, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Default'),
#  Text(0.19976102209013757, 0.8058823529411765, 'install_income_norm <= 0.264\nentropy = 0.811\nsamples = 8\nvalue = [2, 6]\nclass = Default'),
#  Text(0.19780017770152272, 0.7941176470588235, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.20172186647875243, 0.7941176470588235, 'install_income_norm <= 0.264\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]\nclass = Default'),
#  Text(0.19976102209013757, 0.7823529411764706, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Default'),
#  Text(0.20368271086736725, 0.7823529411764706, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.2134869328104415, 0.8176470588235294, 'install_income_norm <= 0.271\nentropy = 0.942\nsamples = 128\nvalue = [82, 46]\nclass = No Default'),
#  Text(0.20760439964459695, 0.8058823529411765, 'jobSector_other <= 0.5\nentropy = 0.592\nsamples = 28\nvalue = [24, 4]\nclass = No Default'),
#  Text(0.2056435552559821, 0.7941176470588235, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = No Default'),
#  Text(0.2095652440332118, 0.7941176470588235, 'install_income_norm <= 0.267\nentropy = 0.89\nsamples = 13\nvalue = [9, 4]\nclass = No Default'),
#  Text(0.20760439964459695, 0.7823529411764706, 'install_income_norm <= 0.266\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]\nclass = No Default'),
#  Text(0.2056435552559821, 0.7705882352941177, 'install_income_norm <= 0.265\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]\nclass = No Default'),
#  Text(0.20368271086736725, 0.7588235294117647, 'install_income_norm <= 0.265\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = No Default'),
#  Text(0.20172186647875243, 0.7470588235294118, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.2056435552559821, 0.7470588235294118, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.20760439964459695, 0.7588235294117647, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No Default'),
#  Text(0.2095652440332118, 0.7705882352941177, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.21152608842182666, 0.7823529411764706, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No Default'),
#  Text(0.21936946597628604, 0.8058823529411765, 'install_income_norm <= 0.288\nentropy = 0.981\nsamples = 100\nvalue = [58, 42]\nclass = No Default'),
#  Text(0.21740862158767119, 0.7941176470588235, 'install_income_norm <= 0.271\nentropy = 0.995\nsamples = 92\nvalue = [50, 42]\nclass = No Default'),
#  Text(0.21544777719905633, 0.7823529411764706, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Default'),
#  Text(0.21936946597628604, 0.7823529411764706, 'install_income_norm <= 0.288\nentropy = 0.987\nsamples = 88\nvalue = [50, 38]\nclass = No Default'),
#  Text(0.21740862158767119, 0.7705882352941177, 'install_income_norm <= 0.272\nentropy = 0.977\nsamples = 85\nvalue = [50, 35]\nclass = No Default'),
#  Text(0.21544777719905633, 0.7588235294117647, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No Default'),
#  Text(0.21936946597628604, 0.7588235294117647, 'install_income_norm <= 0.272\nentropy = 0.984\nsamples = 82\nvalue = [47, 35]\nclass = No Default'),
#  Text(0.21740862158767119, 0.7470588235294118, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.2213303103649009, 0.7470588235294118, 'install_income_norm <= 0.273\nentropy = 0.974\nsamples = 79\nvalue = [47, 32]\nclass = No Default'),
#  Text(0.21936946597628604, 0.7352941176470589, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No Default'),
#  Text(0.22329115475351574, 0.7352941176470589, 'install_income_norm <= 0.274\nentropy = 0.987\nsamples = 74\nvalue = [42, 32]\nclass = No Default'),
#  Text(0.2213303103649009, 0.7235294117647059, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.2252519991421306, 0.7235294117647059, 'install_income_norm <= 0.275\nentropy = 0.976\nsamples = 71\nvalue = [42, 29]\nclass = No Default'),
#  Text(0.22329115475351574, 0.711764705882353, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = No Default'),
#  Text(0.22721284353074542, 0.711764705882353, 'install_income_norm <= 0.276\nentropy = 0.994\nsamples = 64\nvalue = [35, 29]\nclass = No Default'),
#  Text(0.22329115475351574, 0.7, 'jobSector_other <= 0.5\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]\nclass = Default'),
#  Text(0.2213303103649009, 0.6882352941176471, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Default'),
#  Text(0.2252519991421306, 0.6882352941176471, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.23113453230797512, 0.7, 'install_income_norm <= 0.278\nentropy = 0.973\nsamples = 57\nvalue = [34, 23]\nclass = No Default'),
#  Text(0.22917368791936027, 0.6882352941176471, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = No Default'),
#  Text(0.23309537669658997, 0.6882352941176471, 'install_income_norm <= 0.279\nentropy = 0.993\nsamples = 51\nvalue = [28, 23]\nclass = No Default'),
#  Text(0.23113453230797512, 0.6764705882352942, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Default'),
#  Text(0.23505622108520483, 0.6764705882352942, 'install_income_norm <= 0.282\nentropy = 0.956\nsamples = 45\nvalue = [28, 17]\nclass = No Default'),
#  Text(0.23309537669658997, 0.6647058823529411, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]\nclass = No Default'),
#  Text(0.23701706547381968, 0.6647058823529411, 'install_income_norm <= 0.282\nentropy = 0.999\nsamples = 33\nvalue = [16, 17]\nclass = Default'),
#  Text(0.23505622108520483, 0.6529411764705882, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Default'),
#  Text(0.2389779098624345, 0.6529411764705882, 'install_income_norm <= 0.283\nentropy = 0.975\nsamples = 27\nvalue = [16, 11]\nclass = No Default'),
#  Text(0.23701706547381968, 0.6411764705882353, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No Default'),
#  Text(0.24093875425104935, 0.6411764705882353, 'install_income_norm <= 0.283\nentropy = 1.0\nsamples = 22\nvalue = [11, 11]\nclass = No Default'),
#  Text(0.2389779098624345, 0.6294117647058823, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.2428995986396642, 0.6294117647058823, 'jobSector_finance_bank <= 0.5\nentropy = 0.982\nsamples = 19\nvalue = [11, 8]\nclass = No Default'),
#  Text(0.24093875425104935, 0.6176470588235294, 'jobSector_sci_tech <= 0.5\nentropy = 0.896\nsamples = 16\nvalue = [11, 5]\nclass = No Default'),
#  Text(0.2389779098624345, 0.6058823529411764, 'install_income_norm <= 0.286\nentropy = 0.619\nsamples = 13\nvalue = [11, 2]\nclass = No Default'),
#  Text(0.23701706547381968, 0.5941176470588235, 'install_income_norm <= 0.286\nentropy = 0.863\nsamples = 7\nvalue = [5, 2]\nclass = No Default'),
#  Text(0.23505622108520483, 0.5823529411764706, 'install_income_norm <= 0.285\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]\nclass = No Default'),
#  Text(0.23309537669658997, 0.5705882352941176, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No Default'),
#  Text(0.23701706547381968, 0.5705882352941176, 'install_income_norm <= 0.285\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = No Default'),
#  Text(0.23505622108520483, 0.5588235294117647, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Default'),
#  Text(0.2389779098624345, 0.5588235294117647, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.2389779098624345, 0.5823529411764706, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Default'),
#  Text(0.24093875425104935, 0.5941176470588235, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = No Default'),
#  Text(0.2428995986396642, 0.6058823529411764, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.24486044302827906, 0.6176470588235294, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.2213303103649009, 0.7705882352941177, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.2213303103649009, 0.7941176470588235, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = No Default'),
#  Text(0.19829038879867644, 0.8647058823529412, 'install_income_norm <= 0.291\nentropy = 0.65\nsamples = 12\nvalue = [2, 10]\nclass = Default'),
#  Text(0.1963295444100616, 0.8529411764705882, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Default'),
#  Text(0.20025123318729127, 0.8529411764705882, 'install_income_norm <= 0.291\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]\nclass = Default'),
#  Text(0.19829038879867644, 0.8411764705882353, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.20221207757590612, 0.8411764705882353, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.21544777719905633, 0.8764705882352941, 'jobSector_other <= 0.5\nentropy = 0.491\nsamples = 28\nvalue = [25, 3]\nclass = No Default'),
#  Text(0.2134869328104415, 0.8647058823529412, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]\nclass = No Default'),
#  Text(0.21740862158767119, 0.8647058823529412, 'install_income_norm <= 0.296\nentropy = 0.75\nsamples = 14\nvalue = [11, 3]\nclass = No Default'),
#  Text(0.2134869328104415, 0.8529411764705882, 'install_income_norm <= 0.292\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]\nclass = No Default'),
#  Text(0.21152608842182666, 0.8411764705882353, 'install_income_norm <= 0.292\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]\nclass = No Default'),
#  Text(0.2095652440332118, 0.8294117647058824, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = No Default'),
#  Text(0.2134869328104415, 0.8294117647058824, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Default'),
#  Text(0.21544777719905633, 0.8411764705882353, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = No Default'),
#  Text(0.2213303103649009, 0.8529411764705882, 'install_income_norm <= 0.296\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Default'),
#  Text(0.21936946597628604, 0.8411764705882353, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.22329115475351574, 0.8411764705882353, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.6079842234845584, 0.888235294117647, 'jobSector_public_safety <= 0.5\nentropy = 1.0\nsamples = 1688\nvalue = [864, 824]\nclass = No Default'),
#  Text(0.5875790968052024, 0.8764705882352941, 'install_income_norm <= 0.297\nentropy = 1.0\nsamples = 1638\nvalue = [830, 808]\nclass = No Default'),
#  Text(0.5856182524165875, 0.8647058823529412, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Default'),
#  Text(0.5895399411938173, 0.8647058823529412, 'install_income_norm <= 0.297\nentropy = 1.0\nsamples = 1634\nvalue = [830, 804]\nclass = No Default'),
#  Text(0.5875790968052024, 0.8529411764705882, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No Default'),
#  Text(0.591500785582432, 0.8529411764705882, 'install_income_norm <= 0.298\nentropy = 1.0\nsamples = 1629\nvalue = [825, 804]\nclass = No Default'),
#  Text(0.5895399411938173, 0.8411764705882353, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Default'),
#  Text(0.5934616299710469, 0.8411764705882353, 'jobSector_sci_tech <= 0.5\nentropy = 1.0\nsamples = 1623\nvalue = [825, 798]\nclass = No Default'),
#  Text(0.5742206648870982, 0.8294117647058824, 'install_income_norm <= 0.3\nentropy = 0.999\nsamples = 1518\nvalue = [783, 735]\nclass = No Default'),
#  Text(0.5722598204984835, 0.8176470588235294, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No Default'),
#  Text(0.5761815092757131, 0.8176470588235294, 'jobSector_manufacture <= 0.5\nentropy = 0.999\nsamples = 1513\nvalue = [778, 735]\nclass = No Default'),
#  Text(0.5592688673825791, 0.8058823529411765, 'install_income_norm <= 0.557\nentropy = 0.999\nsamples = 1476\nvalue = [766, 710]\nclass = No Default'),
#  Text(0.5573080229939643, 0.7941176470588235, 'install_income_norm <= 0.546\nentropy = 0.999\nsamples = 1473\nvalue = [766, 707]\nclass = No Default'),
#  Text(0.5479932940653819, 0.7823529411764706, 'install_income_norm <= 0.545\nentropy = 0.999\nsamples = 1411\nvalue = [725, 686]\nclass = No Default'),
#  Text(0.546032449676767, 0.7705882352941177, 'install_income_norm <= 0.543\nentropy = 0.999\nsamples = 1403\nvalue = [725, 678]\nclass = No Default'),
#  Text(0.5440716052881522, 0.7588235294117647, 'install_income_norm <= 0.543\nentropy = 0.999\nsamples = 1396\nvalue = [718, 678]\nclass = No Default'),
#  Text(0.5421107608995374, 0.7470588235294118, 'install_income_norm <= 0.542\nentropy = 0.999\nsamples = 1389\nvalue = [718, 671]\nclass = No Default'),
#  Text(0.5401499165109225, 0.7352941176470589, 'install_income_norm <= 0.541\nentropy = 0.999\nsamples = 1386\nvalue = [715, 671]\nclass = No Default'),
# ...
#  Text(0.45123931492999175, 0.40588235294117647, 'install_income_norm <= 0.412\nentropy = 0.971\nsamples = 10\nvalue = [4, 6]\nclass = Default'),
#  Text(0.4492784705413769, 0.3941176470588235, 'install_income_norm <= 0.41\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]\nclass = No Default'),
#  Text(0.44731762615276205, 0.38235294117647056, 'install_income_norm <= 0.41\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = Default'),
#  Text(0.44535678176414717, 0.37058823529411766, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.4492784705413769, 0.37058823529411766, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.45123931492999175, 0.38235294117647056, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No Default'),
#  Text(0.4532001593186066, 0.3941176470588235, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.4404546707926101, 0.45294117647058824, 'entropy = 0.0\nsamples = 19\nvalue = [19, 0]\nclass = No Default'),
#  Text(0.4424155151812249, 0.4647058823529412, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Default'),
#  Text(0.4443763595698398, 0.4764705882352941, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = No Default'),
#  Text(0.45957290358160485, 0.5, 'install_income_norm <= 0.426\nentropy = 0.936\nsamples = 125\nvalue = [44, 81]\nclass = Default'),
#  Text(0.45761205919299, 0.48823529411764705, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Default'),
#  Text(0.4615337479702197, 0.48823529411764705, 'install_income_norm <= 0.426\nentropy = 0.962\nsamples = 114\nvalue = [44, 70]\nclass = Default'),
#  Text(0.45957290358160485, 0.4764705882352941, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No Default'),
#  Text(0.4634945923588345, 0.4764705882352941, 'install_income_norm <= 0.431\nentropy = 0.95\nsamples = 111\nvalue = [41, 70]\nclass = Default'),
#  Text(0.4551610037072214, 0.4647058823529412, 'install_income_norm <= 0.428\nentropy = 0.985\nsamples = 14\nvalue = [8, 6]\nclass = No Default'),
#  Text(0.4532001593186066, 0.45294117647058824, 'install_income_norm <= 0.428\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]\nclass = Default'),
#  Text(0.45123931492999175, 0.4411764705882353, 'install_income_norm <= 0.427\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]\nclass = No Default'),
#  Text(0.4492784705413769, 0.4294117647058823, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Default'),
#  Text(0.4532001593186066, 0.4294117647058823, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.4551610037072214, 0.4411764705882353, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Default'),
#  Text(0.4571218480958363, 0.45294117647058824, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]\nclass = No Default'),
#  Text(0.4718281810104476, 0.4647058823529412, 'install_income_norm <= 0.432\nentropy = 0.925\nsamples = 97\nvalue = [33, 64]\nclass = Default'),
#  Text(0.4698673366218328, 0.45294117647058824, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = Default'),
#  Text(0.4737890253990625, 0.45294117647058824, 'install_income_norm <= 0.44\nentropy = 0.961\nsamples = 86\nvalue = [33, 53]\nclass = Default'),
#  Text(0.461043536873066, 0.4411764705882353, 'install_income_norm <= 0.433\nentropy = 0.863\nsamples = 14\nvalue = [10, 4]\nclass = No Default'),
#  Text(0.4571218480958363, 0.4294117647058823, 'install_income_norm <= 0.432\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Default'),
#  Text(0.4551610037072214, 0.4176470588235294, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.4590826924844511, 0.4176470588235294, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.46496522565029563, 0.4294117647058823, 'install_income_norm <= 0.436\nentropy = 0.684\nsamples = 11\nvalue = [9, 2]\nclass = No Default'),
#  Text(0.4630043812616808, 0.4176470588235294, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No Default'),
#  Text(0.4669260700389105, 0.4176470588235294, 'install_income_norm <= 0.438\nentropy = 0.811\nsamples = 8\nvalue = [6, 2]\nclass = No Default'),
#  Text(0.46496522565029563, 0.40588235294117647, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Default'),
#  Text(0.46888691442752534, 0.40588235294117647, 'install_income_norm <= 0.438\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]\nclass = No Default'),
#  Text(0.4669260700389105, 0.3941176470588235, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No Default'),
#  Text(0.4708477588161402, 0.3941176470588235, 'install_income_norm <= 0.439\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = No Default'),
#  Text(0.46888691442752534, 0.38235294117647056, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Default'),
#  Text(0.47280860320475504, 0.38235294117647056, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No Default'),
#  Text(0.486534513925059, 0.4411764705882353, 'install_income_norm <= 0.442\nentropy = 0.904\nsamples = 72\nvalue = [23, 49]\nclass = Default'),
#  Text(0.4801617696620607, 0.4294117647058823, 'install_income_norm <= 0.441\nentropy = 0.414\nsamples = 12\nvalue = [1, 11]\nclass = Default'),
#  Text(0.4782009252734459, 0.4176470588235294, 'install_income_norm <= 0.441\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Default'),
#  Text(0.47624008088483105, 0.40588235294117647, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.4801617696620607, 0.40588235294117647, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.4821226140506756, 0.4176470588235294, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9]\nclass = Default'),
#  Text(0.49290725818805725, 0.4294117647058823, 'install_income_norm <= 0.459\nentropy = 0.948\nsamples = 60\nvalue = [22, 38]\nclass = Default'),
#  Text(0.4880051472165201, 0.4176470588235294, 'install_income_norm <= 0.455\nentropy = 0.973\nsamples = 52\nvalue = [21, 31]\nclass = Default'),
#  Text(0.4840834584392904, 0.40588235294117647, 'install_income_norm <= 0.453\nentropy = 0.901\nsamples = 41\nvalue = [13, 28]\nclass = Default'),
#  Text(0.4821226140506756, 0.3941176470588235, 'install_income_norm <= 0.452\nentropy = 0.96\nsamples = 34\nvalue = [13, 21]\nclass = Default'),
#  Text(0.47673029198198474, 0.38235294117647056, 'install_income_norm <= 0.449\nentropy = 0.918\nsamples = 30\nvalue = [10, 20]\nclass = Default'),
#  Text(0.4718281810104476, 0.37058823529411766, 'install_income_norm <= 0.445\nentropy = 0.998\nsamples = 19\nvalue = [9, 10]\nclass = Default'),
#  Text(0.46790649223321795, 0.3588235294117647, 'install_income_norm <= 0.444\nentropy = 0.89\nsamples = 13\nvalue = [4, 9]\nclass = Default'),
#  Text(0.4659456478446031, 0.34705882352941175, 'install_income_norm <= 0.443\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]\nclass = No Default'),
#  Text(0.46398480345598825, 0.3352941176470588, 'install_income_norm <= 0.442\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Default'),
#  Text(0.46202395906737337, 0.3235294117647059, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.4659456478446031, 0.3235294117647059, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.46790649223321795, 0.3352941176470588, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No Default'),
#  Text(0.4698673366218328, 0.34705882352941175, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Default'),
#  Text(0.4757498697876773, 0.3588235294117647, 'install_income_norm <= 0.448\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]\nclass = No Default'),
#  Text(0.4737890253990625, 0.34705882352941175, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No Default'),
#  Text(0.4777107141762922, 0.34705882352941175, 'install_income_norm <= 0.448\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = No Default'),
#  Text(0.4757498697876773, 0.3352941176470588, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Default'),
#  Text(0.479671558564907, 0.3352941176470588, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.4816324029535219, 0.37058823529411766, 'install_income_norm <= 0.451\nentropy = 0.439\nsamples = 11\nvalue = [1, 10]\nclass = Default'),
#  Text(0.479671558564907, 0.3588235294117647, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Default'),
#  Text(0.4835932473421367, 0.3588235294117647, 'install_income_norm <= 0.451\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]\nclass = Default'),
#  Text(0.4816324029535219, 0.34705882352941175, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.48555409173075154, 0.34705882352941175, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Default'),
#  Text(0.4875149361193664, 0.38235294117647056, 'install_income_norm <= 0.453\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = No Default'),
#  Text(0.48555409173075154, 0.37058823529411766, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = No Default'),
#  Text(0.48947578050798124, 0.37058823529411766, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.4860443028279053, 0.3941176470588235, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Default'),
#  Text(0.4919268359937498, 0.40588235294117647, 'install_income_norm <= 0.456\nentropy = 0.845\nsamples = 11\nvalue = [8, 3]\nclass = No Default'),
#  Text(0.489965991605135, 0.3941176470588235, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No Default'),
#  Text(0.49388768038236464, 0.3941176470588235, 'install_income_norm <= 0.456\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]\nclass = No Default'),
#  Text(0.4919268359937498, 0.38235294117647056, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.4958485247709795, 0.38235294117647056, 'install_income_norm <= 0.458\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]\nclass = No Default'),
#  Text(0.49388768038236464, 0.37058823529411766, 'install_income_norm <= 0.458\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = No Default'),
#  Text(0.4919268359937498, 0.3588235294117647, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.4958485247709795, 0.3588235294117647, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Default'),
#  Text(0.49780936915959434, 0.37058823529411766, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No Default'),
#  Text(0.49780936915959434, 0.4176470588235294, 'install_income_norm <= 0.46\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]\nclass = Default'),
#  Text(0.4958485247709795, 0.40588235294117647, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Default'),
#  Text(0.4997702135482092, 0.40588235294117647, 'install_income_norm <= 0.461\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Default'),
#  Text(0.49780936915959434, 0.3941176470588235, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.501731057936824, 0.3941176470588235, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.5056527467140537, 0.5117647058823529, 'install_income_norm <= 0.463\nentropy = 0.964\nsamples = 95\nvalue = [58, 37]\nclass = No Default'),
#  Text(0.5036919023254389, 0.5, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = No Default'),
#  Text(0.5076135911026686, 0.5, 'install_income_norm <= 0.465\nentropy = 0.984\nsamples = 87\nvalue = [50, 37]\nclass = No Default'),
#  Text(0.5056527467140537, 0.48823529411764705, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Default'),
#  Text(0.5095744354912835, 0.48823529411764705, 'install_income_norm <= 0.467\nentropy = 0.965\nsamples = 82\nvalue = [50, 32]\nclass = No Default'),
#  Text(0.5076135911026686, 0.4764705882352941, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No Default'),
#  Text(0.5115352798798983, 0.4764705882352941, 'install_income_norm <= 0.467\nentropy = 0.979\nsamples = 77\nvalue = [45, 32]\nclass = No Default'),
#  Text(0.5095744354912835, 0.4647058823529412, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.5134961242685131, 0.4647058823529412, 'install_income_norm <= 0.47\nentropy = 0.971\nsamples = 75\nvalue = [45, 30]\nclass = No Default'),
#  Text(0.5115352798798983, 0.45294117647058824, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = No Default'),
#  Text(0.515456968657128, 0.45294117647058824, 'install_income_norm <= 0.47\nentropy = 0.985\nsamples = 70\nvalue = [40, 30]\nclass = No Default'),
#  Text(0.5134961242685131, 0.4411764705882353, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.5174178130457429, 0.4411764705882353, 'install_income_norm <= 0.48\nentropy = 0.973\nsamples = 67\nvalue = [40, 27]\nclass = No Default'),
#  Text(0.5134961242685131, 0.4294117647058823, 'install_income_norm <= 0.48\nentropy = 1.0\nsamples = 39\nvalue = [20, 19]\nclass = No Default'),
#  Text(0.5115352798798983, 0.4176470588235294, 'install_income_norm <= 0.479\nentropy = 0.977\nsamples = 34\nvalue = [20, 14]\nclass = No Default'),
#  Text(0.5095744354912835, 0.40588235294117647, 'install_income_norm <= 0.479\nentropy = 0.989\nsamples = 32\nvalue = [18, 14]\nclass = No Default'),
#  Text(0.5076135911026686, 0.3941176470588235, 'install_income_norm <= 0.477\nentropy = 0.94\nsamples = 28\nvalue = [18, 10]\nclass = No Default'),
#  Text(0.5056527467140537, 0.38235294117647056, 'install_income_norm <= 0.476\nentropy = 0.994\nsamples = 22\nvalue = [12, 10]\nclass = No Default'),
#  Text(0.5036919023254389, 0.37058823529411766, 'install_income_norm <= 0.473\nentropy = 0.949\nsamples = 19\nvalue = [12, 7]\nclass = No Default'),
#  Text(0.4997702135482092, 0.3588235294117647, 'install_income_norm <= 0.473\nentropy = 0.971\nsamples = 10\nvalue = [4, 6]\nclass = Default'),
#  Text(0.49780936915959434, 0.34705882352941175, 'install_income_norm <= 0.47\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]\nclass = No Default'),
#  Text(0.4958485247709795, 0.3352941176470588, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.4997702135482092, 0.3352941176470588, 'install_income_norm <= 0.47\nentropy = 0.985\nsamples = 7\nvalue = [3, 4]\nclass = Default'),
#  Text(0.49780936915959434, 0.3235294117647059, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.501731057936824, 0.3235294117647059, 'install_income_norm <= 0.47\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]\nclass = No Default'),
#  Text(0.4997702135482092, 0.31176470588235294, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.5036919023254389, 0.31176470588235294, 'install_income_norm <= 0.472\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = Default'),
#  Text(0.501731057936824, 0.3, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.5056527467140537, 0.3, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = No Default'),
#  Text(0.501731057936824, 0.34705882352941175, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = Default'),
#  Text(0.5076135911026686, 0.3588235294117647, 'install_income_norm <= 0.475\nentropy = 0.503\nsamples = 9\nvalue = [8, 1]\nclass = No Default'),
#  Text(0.5056527467140537, 0.34705882352941175, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = No Default'),
#  Text(0.5095744354912835, 0.34705882352941175, 'install_income_norm <= 0.476\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = No Default'),
#  Text(0.5076135911026686, 0.3352941176470588, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Default'),
#  Text(0.5115352798798983, 0.3352941176470588, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.5076135911026686, 0.37058823529411766, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Default'),
#  Text(0.5095744354912835, 0.38235294117647056, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = No Default'),
#  Text(0.5115352798798983, 0.3941176470588235, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Default'),
#  Text(0.5134961242685131, 0.40588235294117647, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = No Default'),
#  Text(0.515456968657128, 0.4176470588235294, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = Default'),
#  ...]

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
y_pred = tree.predict(X_test)
cf_matrix=confusion_matrix(y_pred,Y_test)

plt.figure(figsize= (5,5))
dis = ConfusionMatrixDisplay(confusion_matrix= cf_matrix, display_labels=['No Default', 'Default'])
dis.plot(cmap=plt.cm.Blues)
plt.show()

cf_matrix=confusion_matrix(y_pred,Y_test)
TN = cf_matrix[0, 0]
FP = cf_matrix[0, 1]
FN = cf_matrix[1, 0]
TP = cf_matrix[1, 1]

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
acc = accuracy_score(Y_test, y_pred)
prec = precision_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)
error_rate = (FP + FN)/ (TP + TN + FP)
print("accuracy_score : ", acc)
print("precision_score : ", prec)
print("recall_score : ", recall)
print("f1_score : ", f1)
print("error rate: ", error_rate)
# Out:
# accuracy_score :  0.8519345238095238
# precision_score :  0.803088803088803
# recall_score :  0.9313432835820895
# f1_score :  0.8624740843123703
# error rate:  0.1670864819479429

# %% [markdown]
# Pruning of our Decision Tree

# %%
path = tree.cost_complexity_pruning_path(X_train, Y_train)
ccp_alphas = path.ccp_alphas
ccp_alphas = ccp_alphas[:-1]

trees = []

for ccp_alpha in ccp_alphas:
    tree = DecisionTreeClassifier(criterion= "entropy", random_state= 0, ccp_alpha = ccp_alpha)
    tree.fit(X_train, Y_train)
    trees.append(tree)

# %%
train_scores = [tree.score(X_train, Y_train) for tree in trees]
test_scores  = [tree.score(X_test, Y_test) for tree in trees]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("accuracy")
ax.set_title("Accuracy vs alpha for training and testing sets")
ax.plot(ccp_alphas, train_scores, marker = "o", label = "train", drawstyle = "steps-post")
ax.plot(ccp_alphas, test_scores, marker = "o", label = "test", drawstyle = "steps-post")
ax.legend()
plt.show()

# %% [markdown]
# CROSS VALIDATION FOR TREE PRUNING

# %%
alpah_loop_values = []
from sklearn.model_selection import cross_val_score
for ccp_alpha in ccp_alphas:
    tree = DecisionTreeClassifier(criterion= "entropy", random_state= 0, ccp_alpha= ccp_alpha)
    scores = cross_val_score(tree, X_train, Y_train, cv = 10)
    alpah_loop_values.append([ccp_alpha, np.mean(scores), np.std(scores)])


alpha_results = pd.DataFrame(alpah_loop_values,
                             columns = ['alpha', 'mean_accuracy', 'std'])

alpha_results.plot(x = 'alpha',
                   y = 'mean_accuracy',
                   yerr = 'std',
                   marker = 'o',
                   linestyle = '--')
# Out:
# <AxesSubplot: xlabel='alpha'>

# %%
ideal_ccp_alpha = alpha_results[alpha_results['mean_accuracy'] == alpha_results.mean_accuracy.max()]['alpha']
ideal_ccp_alpha = float(ideal_ccp_alpha)

# %%
ideal_ccp_alpha
# Out:
# 0.0033116941062351773

# %%
tree_pruned = DecisionTreeClassifier(criterion = "entropy", ccp_alpha = ideal_ccp_alpha, random_state = 100).fit(X_train, Y_train)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
y_pred = tree_pruned.predict(X_test)
cf_matrix=confusion_matrix(y_pred,Y_test)

plt.figure(figsize= (5,5))
dis = ConfusionMatrixDisplay(confusion_matrix= cf_matrix, display_labels=['No Default', 'Default'])
dis.plot(cmap=plt.cm.Blues)
plt.show()

cf_matrix=confusion_matrix(y_pred,Y_test)
TN = cf_matrix[0, 0]
FP = cf_matrix[0, 1]
FN = cf_matrix[1, 0]
TP = cf_matrix[1, 1]

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
acc = accuracy_score(Y_test, y_pred)
prec = precision_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)
error_rate = (FP + FN)/ (TP + TN + FP)
print("accuracy_score : ", acc)
print("precision_score : ", prec)
print("recall_score : ", recall)
print("f1_score : ", f1)
print("error rate: ", error_rate)
# Out:
# accuracy_score :  0.6182266009852216
# precision_score :  0.6455026455026455
# recall_score :  0.580952380952381
# f1_score :  0.6115288220551379
# error rate:  0.45722713864306785

# %%
# Plot of Tree
plt.figure(figsize=(20,10))
from sklearn.tree import plot_tree
plot_tree(tree_pruned,
          filled = True,
          rounded= True,
          class_names=["No Default", "Default"],

          feature_names= X.columns)
# Out:
# [Text(0.4264705882352941, 0.9545454545454546, 'install_income_norm <= 0.285\nentropy = 1.0\nsamples = 1218\nvalue = [616, 602]\nclass = No Default'),
#  Text(0.11764705882352941, 0.8636363636363636, 'home_own_RENT <= 0.5\nentropy = 0.901\nsamples = 259\nvalue = [177, 82]\nclass = No Default'),
#  Text(0.058823529411764705, 0.7727272727272727, 'entropy = 0.814\nsamples = 151\nvalue = [113, 38]\nclass = No Default'),
#  Text(0.17647058823529413, 0.7727272727272727, 'install_income_norm <= 0.154\nentropy = 0.975\nsamples = 108\nvalue = [64, 44]\nclass = No Default'),
#  Text(0.11764705882352941, 0.6818181818181818, 'entropy = 0.667\nsamples = 23\nvalue = [19, 4]\nclass = No Default'),
#  Text(0.23529411764705882, 0.6818181818181818, 'install_income_norm <= 0.276\nentropy = 0.998\nsamples = 85\nvalue = [45, 40]\nclass = No Default'),
#  Text(0.17647058823529413, 0.5909090909090909, 'install_income_norm <= 0.266\nentropy = 0.999\nsamples = 75\nvalue = [36, 39]\nclass = Default'),
#  Text(0.11764705882352941, 0.5, 'install_income_norm <= 0.168\nentropy = 0.999\nsamples = 69\nvalue = [36, 33]\nclass = No Default'),
#  Text(0.058823529411764705, 0.4090909090909091, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Default'),
#  Text(0.17647058823529413, 0.4090909090909091, 'install_income_norm <= 0.183\nentropy = 0.992\nsamples = 65\nvalue = [36, 29]\nclass = No Default'),
#  Text(0.11764705882352941, 0.3181818181818182, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = No Default'),
#  Text(0.23529411764705882, 0.3181818181818182, 'install_income_norm <= 0.251\nentropy = 1.0\nsamples = 57\nvalue = [28, 29]\nclass = Default'),
#  Text(0.17647058823529413, 0.22727272727272727, 'install_income_norm <= 0.231\nentropy = 0.961\nsamples = 39\nvalue = [15, 24]\nclass = Default'),
#  Text(0.11764705882352941, 0.13636363636363635, 'install_income_norm <= 0.207\nentropy = 0.999\nsamples = 29\nvalue = [14, 15]\nclass = Default'),
#  Text(0.058823529411764705, 0.045454545454545456, 'entropy = 0.779\nsamples = 13\nvalue = [3, 10]\nclass = Default'),
#  Text(0.17647058823529413, 0.045454545454545456, 'entropy = 0.896\nsamples = 16\nvalue = [11, 5]\nclass = No Default'),
#  Text(0.23529411764705882, 0.13636363636363635, 'entropy = 0.469\nsamples = 10\nvalue = [1, 9]\nclass = Default'),
#  Text(0.29411764705882354, 0.22727272727272727, 'entropy = 0.852\nsamples = 18\nvalue = [13, 5]\nclass = No Default'),
#  Text(0.23529411764705882, 0.5, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Default'),
#  Text(0.29411764705882354, 0.5909090909090909, 'entropy = 0.469\nsamples = 10\nvalue = [9, 1]\nclass = No Default'),
#  Text(0.7352941176470589, 0.8636363636363636, 'install_income_norm <= 0.559\nentropy = 0.995\nsamples = 959\nvalue = [439, 520]\nclass = Default'),
#  Text(0.5882352941176471, 0.7727272727272727, 'home_own_RENT <= 0.5\nentropy = 1.0\nsamples = 560\nvalue = [278, 282]\nclass = Default'),
#  Text(0.47058823529411764, 0.6818181818181818, 'install_income_norm <= 0.543\nentropy = 0.994\nsamples = 331\nvalue = [180, 151]\nclass = No Default'),
#  Text(0.4117647058823529, 0.5909090909090909, 'install_income_norm <= 0.288\nentropy = 0.997\nsamples = 317\nvalue = [168, 149]\nclass = No Default'),
#  Text(0.35294117647058826, 0.5, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Default'),
#  Text(0.47058823529411764, 0.5, 'entropy = 0.996\nsamples = 313\nvalue = [168, 145]\nclass = No Default'),
#  Text(0.5294117647058824, 0.5909090909090909, 'entropy = 0.592\nsamples = 14\nvalue = [12, 2]\nclass = No Default'),
#  Text(0.7058823529411765, 0.6818181818181818, 'install_income_norm <= 0.31\nentropy = 0.985\nsamples = 229\nvalue = [98, 131]\nclass = Default'),
#  Text(0.6470588235294118, 0.5909090909090909, 'entropy = 0.837\nsamples = 15\nvalue = [11, 4]\nclass = No Default'),
#  Text(0.7647058823529411, 0.5909090909090909, 'install_income_norm <= 0.555\nentropy = 0.975\nsamples = 214\nvalue = [87, 127]\nclass = Default'),
#  Text(0.7058823529411765, 0.5, 'install_income_norm <= 0.549\nentropy = 0.97\nsamples = 211\nvalue = [84, 127]\nclass = Default'),
#  Text(0.6470588235294118, 0.4090909090909091, 'entropy = 0.977\nsamples = 204\nvalue = [84, 120]\nclass = Default'),
#  Text(0.7647058823529411, 0.4090909090909091, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = Default'),
#  Text(0.8235294117647058, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = No Default'),
#  Text(0.8823529411764706, 0.7727272727272727, 'install_income_norm <= 0.563\nentropy = 0.973\nsamples = 399\nvalue = [161, 238]\nclass = Default'),
#  Text(0.8235294117647058, 0.6818181818181818, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = Default'),
#  Text(0.9411764705882353, 0.6818181818181818, 'entropy = 0.976\nsamples = 393\nvalue = [161, 232]\nclass = Default')]
